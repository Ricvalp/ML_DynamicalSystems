# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Generate the (noisy) training dataset

# %%
function LV(du, u, p, t)
    A, B, C, D = p
    du[1] = A*u[1] - B*u[1]*u[2]
    du[2] = C*u[2] - D*u[1]*u[2]
end


p_ = Float32[1.3, 0.9, 0.8, 1.8]


# Define the experimental parameter

tspan = (0.0f0, 3.0f0)
u0 = Float32[0.5, 1.5]
p_ = Float32[1.3, 0.9, -1.8, -0.8]

prob = ODEProblem(LV, u0, tspan, p_)

solution = solve(prob, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.1)


X = Array(solution)

# Add noise to the data
println("Generate noisy data")
Xₙ = X + Float32(1e-4)*randn(eltype(X), size(X));
# Out:
# Generate noisy data

# %% [markdown]
# ## Plot the training dataset

# %%
#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])
plot(solution.t, Xₙ[1, :])
plot!(solution.t, Xₙ[2, :])

# %% [markdown]
# ## UADE

# %%
# Neural network

L = FastChain(FastDense(2, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 2))
p = initial_params(L)


# ODE

function dudt_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x - p_[2]*z[1],
    p_[3]*y  - p_[4]*z[2]]
end

# ODE problem
prob_nn = ODEProblem(dudt_, u0, tspan, p)
sol_nn = solve(prob_nn, Tsit5(), u0 = u0, p = p, saveat = 0.1);

# %% [markdown]
# ## Plot the untrained solution

# %%
plot(sol_nn)
#plot(Array(sol_nn)[1, :], Array(sol_nn)[2, :])

# %% [markdown]
# ## Loss function

# %%
# This function is used in the loss
function predict(θ)
    Array(solve(prob_nn, Vern7(), u0 = u0, p=θ, saveat = 0.1,
                         abstol=1e-6, reltol=1e-6,
                         sensealg = InterpolatingAdjoint(autojacvec=ReverseDiffVJP())))
end


# No regularisation right now
function loss(θ)
    pred = predict(θ)
    sum(abs2, Xₙ .- pred)
end


# Test
#loss(p)


const losses = []

# The callback function is cb(p,args...) where the arguments are the extra returns from the loss
callback(θ, l) = begin
    push!(losses, l)
    if length(losses)%10==0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")    
    end
    
    # The callback function must return a boolean where if true, then the optimizer will prematurely end the optimization
    false
end
# Out:
# WARNING: redefining constant losses
# callback (generic function with 1 method)

# %% [markdown]
# ## Training with ADAM

# %%
# Train with ADAM
res1 = DiffEqFlux.sciml_train(loss, p, ADAM(0.01), cb=callback, maxiters = 1300)
# Out:
# loss: 249:   1%|█                                       |  ETA: 0:07:25
# Current loss after 10 iterations: 249.21327
# loss: 192:   2%|█                                       |  ETA: 0:06:49
# Current loss after 20 iterations: 192.35893
# loss: 48.2:   2%|█                                      |  ETA: 0:06:22
# Current loss after 30 iterations: 48.190876
# loss: 27.2:   3%|██                                     |  ETA: 0:06:36
# Current loss after 40 iterations: 27.236485
# loss: 17.3:   4%|██                                     |  ETA: 0:06:37
# Current loss after 50 iterations: 17.251465
# loss: 15.3:   5%|██                                     |  ETA: 0:06:33
# Current loss after 1280 iterations: 0.43557078
# loss: 0.433:  99%|██████████████████████████████████████|  ETA: 0:00:02
# Current loss after 1290 iterations: 0.43332714
# loss: 0.431: 100%|██████████████████████████████████████| Time: 0:05:00
# Current loss after 1300 iterations: 0.43105918
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     4.310592e-01
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   307  (vs limit Inf)
#     Iterations:    1300
#     f(x) calls:    1300
#     ∇f(x) calls:   1300

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res2.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 10000)
# Out:
# Current loss after 1410 iterations: 4.751863e-5
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     4.751863e-05
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.86e-09 ≰ 0.0e+00
#     |x - x'|/|x'|          = 1.27e-09 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 1.54e-01 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   10  (vs limit Inf)
#     Iterations:    2
#     f(x) calls:    46
#     ∇f(x) calls:   46

# %% [markdown]
# ## Plot the loss

# %%
plot(losses, yaxis=:log, xlabel = "Iterations", ylabel = "Loss")

# %% [markdown]
# ## Prediction

# %%
function dudt2_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x - p_[2]*z[1],
    p_[3]*y  - p_[4]*z[2]]
end

# ODE problem
tspan2 = (0.0f0, 10.0f0)
prob_nn2 = ODEProblem(dudt2_, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = 0.1);

# %% [markdown]
# ## Plot the approximator prediction

# %%
plot(sol_nn2)
#scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :])

# %% [markdown]
# ## Plot the approximation and the original data

# %%
# Plot the data and the approximation
NNsolution = predict(res2.minimizer)
# Trained on noisy data vs real solution
plot(solution.t, NNsolution')
scatter!(solution.t, X')

# %% [markdown]
# ## Test the prediction

# %%
tspan_test = (0.0f0, 10.0f0)
prob_test = ODEProblem(LV, u0, tspan_test, p_)
solution_test = solve(prob_test, Vern7(), saveat = 0.1);

# %% [markdown]
# ## Plot Toghether True And Prediction
# ### Phase Space Plot

# %%
scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :])
scatter!(Array(solution)[1, :], Array(solution)[2, :])
plot!(Array(solution_test)[1, :], Array(solution_test)[2, :])

# %% [markdown]
# ## Plot $x(t)$ and $y(t)$

# %%
plot(sol_nn2)
scatter!(solution_test.t, Array(solution_test)[1, :])
scatter!(solution_test.t, Array(solution_test)[2, :])
