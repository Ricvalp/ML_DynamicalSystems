# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
gr()
# Out:
# ┌ Info: Precompiling DataDrivenDiffEq [2445eb08-9709-466a-b3fc-47e12bd697a2]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling DiffEqSensitivity [41bf760c-e81c-5289-8e54-58b1f1f8abe2]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling DiffEqFlux [aae7a2af-3d4f-5e19-a356-7da93b79d9d0]
# └ @ Base loading.jl:1260
# Plots.GRBackend()

# %% [markdown]
# ## Generate The (Noisy) Training Dataset

# %%
# 2D Normal Hopf

function Hopf2D(du, u, p, t)
    μ, ω, A = p
    du[1] = μ*u[1] - ω*u[2] - A*u[1]*(u[1]^(2) + u[2]^(2))
    du[2] = μ*u[2] + ω*u[1] - A*u[2]*(u[1]^(2) + u[2]^(2))
end


# Define the experimental parameter

tspan = (0.0f0, 3.0f0)
u0 = Float32[-0.1, 0.1]
p_ = Float32[0.8, 1, 1]

prob = ODEProblem(Hopf2D, u0,tspan, p_)

solution = solve(prob, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.05)


X = Array(solution)

# Add noise to the data
println("Generate noisy data")
Xₙ = X + Float32(1e-3)*randn(eltype(X), size(X));
# Out:
# Generate noisy data

# %% [markdown]
# ## Plot The Training Dataset

# %%
#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])
plot(Xₙ[1, :])
plot!(Xₙ[2, :])

# %% [markdown]
# ## UADE

# %%
# Neural network

L = FastChain(FastDense(2, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 2))
p = initial_params(L)


# ODE

function dudt_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x - p_[2]*y - p_[3]*z[1],
    p_[2]*x + p_[1]*y - p_[3]*z[2]]
end

# ODE problem

prob_nn = ODEProblem(dudt_, u0, tspan, p)
sol_nn = solve(prob_nn, Tsit5(), u0 = u0, p = p, saveat = 0.05);

# %% [markdown]
# ## PLot The Untrained Solution

# %%
plot(sol_nn)
#plot(Array(sol_nn)[1, :], Array(sol_nn)[2, :])

# %% [markdown]
# ## Loss Function

# %%
# This function is used in the loss
function predict(θ)
    Array(solve(prob_nn, Vern7(), u0 = u0, p=θ, saveat = 0.05,
                         abstol=1e-6, reltol=1e-6,
                         sensealg = InterpolatingAdjoint(autojacvec=ReverseDiffVJP())))
end


# No regularisation right now
function loss(θ)
    pred = predict(θ)
    sum(abs2, Xₙ .- pred)
end


# Test
#loss(p)


const losses = []

# The callback function is cb(p,args...) where the arguments are the extra returns from the loss
callback(θ, l) = begin
    push!(losses, l)
    if length(losses)%10==0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")    
    end
    
    # The callback function must return a boolean where if true, then the optimizer will prematurely end the optimization
    false
end
# Out:
# WARNING: redefining constant losses
# callback (generic function with 2 methods)

# %% [markdown]
# ## Training With ADAM

# %%
# Train with ADAM
res1 = DiffEqFlux.sciml_train(loss, p, ADAM(0.01), cb=callback, maxiters = 400)
# Out:
# loss: 4.95:   2%|█                                      |  ETA: 0:04:17
# Current loss after 10 iterations: 4.9509325
# loss: 3.9:   5%|███                                     |  ETA: 0:04:01
# Current loss after 20 iterations: 3.8992605
# loss: 1.65:   8%|███                                    |  ETA: 0:04:11
# Current loss after 30 iterations: 1.6503106
# loss: 0.941:  10%|████                                  |  ETA: 0:03:58
# Current loss after 40 iterations: 0.941167
# loss: 0.879:  12%|█████                                 |  ETA: 0:03:52
# Current loss after 50 iterations: 0.8792425
# loss: 0.831:  15%|██████                                |  ETA: 0:03:42
# Current loss after 60 iterations: 0.8309819
# loss: 0.757:  18%|███████                               |  ETA: 0:03:31
# Current loss after 70 iterations: 0.7566875
# loss: 0.693:  20%|████████                              |  ETA: 0:03:22
# Current loss after 80 iterations: 0.69258714
# loss: 0.626:  22%|█████████                             |  ETA: 0:03:14
# Current loss after 90 iterations: 0.6259475
# loss: 0.547:  25%|██████████                            |  ETA: 0:03:05
# Current loss after 100 iterations: 0.5467525
# loss: 0.462:  28%|███████████                           |  ETA: 0:02:57
# Current loss after 110 iterations: 0.46201056
# loss: 0.374:  30%|████████████                          |  ETA: 0:02:49
# Current loss after 120 iterations: 0.37367392
# loss: 0.288:  32%|█████████████                         |  ETA: 0:02:41
# Current loss after 130 iterations: 0.287637
# loss: 0.21:  35%|██████████████                         |  ETA: 0:02:34
# Current loss after 140 iterations: 0.20969705
# loss: 0.145:  38%|███████████████                       |  ETA: 0:02:27
# Current loss after 150 iterations: 0.14458935
# loss: 0.0946:  40%|███████████████                      |  ETA: 0:02:18
# Current loss after 160 iterations: 0.094560675
# loss: 0.059:  42%|█████████████████                     |  ETA: 0:02:11
# Current loss after 170 iterations: 0.0590006
# loss: 0.0355:  45%|█████████████████                    |  ETA: 0:02:04
# Current loss after 180 iterations: 0.035456654
# loss: 0.0209:  48%|██████████████████                   |  ETA: 0:01:57
# Current loss after 190 iterations: 0.0208656
# loss: 0.0124:  50%|███████████████████                  |  ETA: 0:01:50
# Current loss after 200 iterations: 0.012385031
# loss: 0.00777:  52%|███████████████████                 |  ETA: 0:01:42
# Current loss after 210 iterations: 0.0077710073
# loss: 0.00543:  55%|████████████████████                |  ETA: 0:01:35
# Current loss after 220 iterations: 0.005431825
# loss: 0.00434:  58%|█████████████████████               |  ETA: 0:01:28
# Current loss after 230 iterations: 0.0043353876
# loss: 0.00386:  60%|██████████████████████              |  ETA: 0:01:21
# Current loss after 240 iterations: 0.0038604895
# loss: 0.00367:  62%|███████████████████████             |  ETA: 0:01:14
# Current loss after 250 iterations: 0.0036689318
# loss: 0.00359:  65%|████████████████████████            |  ETA: 0:01:08
# Current loss after 260 iterations: 0.0035934607
# loss: 0.00356:  68%|█████████████████████████           |  ETA: 0:01:01
# Current loss after 270 iterations: 0.003560789
# loss: 0.00354:  70%|██████████████████████████          |  ETA: 0:00:56
# Current loss after 280 iterations: 0.0035412745
# loss: 0.00352:  72%|███████████████████████████         |  ETA: 0:00:50
# Current loss after 290 iterations: 0.003524364
# loss: 0.00351:  75%|████████████████████████████        |  ETA: 0:00:45
# Current loss after 300 iterations: 0.0035079163
# loss: 0.00349:  78%|████████████████████████████        |  ETA: 0:00:39
# Current loss after 310 iterations: 0.00349109
# loss: 0.00347:  80%|█████████████████████████████       |  ETA: 0:00:35
# Current loss after 320 iterations: 0.0034743461
# loss: 0.00346:  82%|██████████████████████████████      |  ETA: 0:00:30
# Current loss after 330 iterations: 0.0034567488
# loss: 0.00344:  85%|███████████████████████████████     |  ETA: 0:00:25
# Current loss after 340 iterations: 0.003439109
# loss: 0.00342:  88%|████████████████████████████████    |  ETA: 0:00:21
# Current loss after 350 iterations: 0.003421369
# loss: 0.0034:  90%|██████████████████████████████████   |  ETA: 0:00:16
# Current loss after 360 iterations: 0.0034042126
# loss: 0.00339:  92%|██████████████████████████████████  |  ETA: 0:00:12
# Current loss after 370 iterations: 0.003385182
# loss: 0.00337:  95%|███████████████████████████████████ |  ETA: 0:00:08
# Current loss after 380 iterations: 0.0033672042
# loss: 0.00335:  98%|████████████████████████████████████|  ETA: 0:00:04
# Current loss after 390 iterations: 0.0033484993
# loss: 0.00333: 100%|████████████████████████████████████| Time: 0:02:35
# Current loss after 400 iterations: 0.0033295138
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     3.329514e-03
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   162  (vs limit Inf)
#     Iterations:    400
#     f(x) calls:    400
#     ∇f(x) calls:   400

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res1.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 10000)
# Out:
# Current loss after 410 iterations: 0.002143422
# Current loss after 420 iterations: 0.0004881385
# Current loss after 430 iterations: 0.000197825
# Current loss after 440 iterations: 0.00015251843
# Current loss after 450 iterations: 0.00013967106
# Current loss after 460 iterations: 0.00013100034
# Current loss after 470 iterations: 0.00012456725
# Current loss after 480 iterations: 0.00012322493
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.232249e-04
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.75e-10 ≰ 0.0e+00
#     |x - x'|/|x'|          = 2.53e-10 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 4.66e-04 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   105  (vs limit Inf)
#     Iterations:    80
#     f(x) calls:    434
#     ∇f(x) calls:   434

# %% [markdown]
# ## Prediction

# %%
function dudt2_(u, p, t)
    x, y = u
    z = L(u, p)
    [p_[1]*x - p_[2]*y - p_[3]*z[1],
    p_[2]*x + p_[1]*y - p_[3]*z[2]]
end

# ODE problem
tspan2 = (0.0f0, 6.0f0)
prob_nn2 = ODEProblem(dudt2_, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = 0.05);

# %% [markdown]
# ## Plot The Prediction

# %%
plot(sol_nn2)
#scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :])

# %% [markdown]
# ## Test The Prediction

# %%
tspan_test = (0.0f0, 6.0f0)
u0 = Float32[-0.1, 0.1]
p_ = Float32[0.8, 1, 1]
prob_test = ODEProblem(Hopf2D, u0, tspan_test, p_)
solution_test = solve(prob_test, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.05);

# %% [markdown]
# ## Plot Toghether True And Prediction
# ### Phase Space Plot

# %%
scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :])
plot!(Array(solution_test)[1, :], Array(solution_test)[2, :])

# %% [markdown]
# ## Plot $x(t)$ and $y(t)$

# %%
plot(sol_nn2)
scatter!(solution_test.t, Array(solution_test)[1, :])
scatter!(solution_test.t, Array(solution_test)[2, :])
