# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Generate the (noisy) training dataset from:
#
#
# ## $$
# \begin{aligned}
#   \dot{x} &= \mu x - \omega y + A_{1} x(x^{2} + y^{2})\\
#   \dot{y} &=  \mu y + \omega y + A_{2} y(x^{2} + y^{2})\\
#   A_{1} &= A_{2}
# \end{aligned}
# $$

# %%
function Hopf2D(du, u, p, t)
    μ, ω, A1, A2 = p
    du[1] = μ*u[1] - ω*u[2] + A1*u[1]*(u[1]^(2) + u[2]^(2))
    du[2] = μ*u[2] + ω*u[1] + A2*u[2]*(u[1]^(2) + u[2]^(2))
end


# Define the experimental parameter

tspan = (0.0f0, 4.0f0)
u0 = Float32[-0.2, 0.2]
p_ = Float32[0.8, 1.2, -1.5, -1.5]

prob = ODEProblem(Hopf2D, u0, tspan, p_)

solution = solve(prob, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.1)


X = Array(solution)

# Add noise to the data
println("Generate noisy data")
Xₙ = X + Float32(1e-4)*randn(eltype(X), size(X));
# Out:
# Generate noisy data

# %% [markdown]
# ## Plot The Training Dataset

# %%
#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])
plot(Xₙ[1, :])
plot!(Xₙ[2, :])

# %% [markdown]
# ## UADE

# %%
# Neural network

L = FastChain(FastDense(2, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 2))
p = initial_params(L)


# ODE

function dudt_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x - p_[2]*y + z[1],
    p_[2]*x + p_[1]*y + z[2]]
end

# ODE problem

prob_nn = ODEProblem(dudt_, u0, tspan, p)
sol_nn = solve(prob_nn, Tsit5(), u0 = u0, p = p, saveat = solution.t);

# %% [markdown]
# ## PLot The Untrained Solution

# %%
plot(sol_nn)
#plot(Array(sol_nn)[1, :], Array(sol_nn)[2, :])

# %% [markdown]
# ## Loss Function

# %%
# This function is used in the loss
function predict(θ)
    Array(solve(prob_nn, Vern7(), u0 = u0, p=θ, saveat = solution.t,
                         abstol=1e-6, reltol=1e-6,
                         sensealg = InterpolatingAdjoint(autojacvec=ReverseDiffVJP())))
end


# No regularisation right now
function loss(θ)
    pred = predict(θ)
    sum(abs2, Xₙ .- pred)
end


# Test
#loss(p)


const losses = []

# The callback function is cb(p,args...) where the arguments are the extra returns from the loss
callback(θ, l) = begin
    push!(losses, l)
    if length(losses)%10==0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")    
    end
    
    # The callback function must return a boolean where if true, then the optimizer will prematurely end the optimization
    false
end
# Out:
# callback (generic function with 1 method)

# %% [markdown]
# ## Training With ADAM

# %%
# Train with ADAM
res1 = DiffEqFlux.sciml_train(loss, p, ADAM(0.01), cb=callback, maxiters = 200)
# Out:
# loss: 14.2:   5%|██                                     |  ETA: 0:02:09
# Current loss after 10 iterations: 14.158966
# loss: 12.1:  10%|████                                   |  ETA: 0:01:51
# Current loss after 20 iterations: 12.083382
# loss: 11.9:  15%|██████                                 |  ETA: 0:01:39
# Current loss after 30 iterations: 11.862261
# loss: 10.5:  20%|████████                               |  ETA: 0:01:31
# Current loss after 40 iterations: 10.460082
# loss: 9.79:  25%|██████████                             |  ETA: 0:01:26
# Current loss after 50 iterations: 9.790827
# loss: 13.2:  30%|████████████                           |  ETA: 0:01:22
# Current loss after 60 iterations: 13.151781
# loss: 12.8:  35%|██████████████                         |  ETA: 0:01:15
# Current loss after 70 iterations: 12.790028
# loss: 12.7:  40%|████████████████                       |  ETA: 0:01:09
# Current loss after 80 iterations: 12.672898
# loss: 12.6:  45%|██████████████████                     |  ETA: 0:01:02
# Current loss after 90 iterations: 12.613068
# loss: 12.5:  50%|████████████████████                   |  ETA: 0:00:55
# Current loss after 100 iterations: 12.528757
# loss: 12.4:  55%|██████████████████████                 |  ETA: 0:00:49
# Current loss after 110 iterations: 12.401309
# loss: 12.2:  60%|████████████████████████               |  ETA: 0:00:43
# Current loss after 120 iterations: 12.212458
# loss: 11.9:  65%|██████████████████████████             |  ETA: 0:00:38
# Current loss after 130 iterations: 11.909477
# loss: 11.4:  70%|████████████████████████████           |  ETA: 0:00:32
# Current loss after 140 iterations: 11.384975
# loss: 10.7:  75%|██████████████████████████████         |  ETA: 0:00:27
# Current loss after 150 iterations: 10.705519
# loss: 9.97:  80%|████████████████████████████████       |  ETA: 0:00:22
# Current loss after 160 iterations: 9.970848
# loss: 8.88:  85%|██████████████████████████████████     |  ETA: 0:00:16
# Current loss after 170 iterations: 8.883816
# loss: 7.39:  90%|████████████████████████████████████   |  ETA: 0:00:11
# Current loss after 180 iterations: 7.391726
# loss: 5.43:  95%|██████████████████████████████████████ |  ETA: 0:00:05
# Current loss after 190 iterations: 5.4326954
# loss: 4.43: 100%|███████████████████████████████████████| Time: 0:01:47
# Current loss after 200 iterations: 4.425497
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     4.425497e+00
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   159  (vs limit Inf)
#     Iterations:    200
#     f(x) calls:    200
#     ∇f(x) calls:   200

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res1.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 10000)
# Out:
# Current loss after 210 iterations: 1.7672212
# Current loss after 220 iterations: 0.1927235
# Current loss after 230 iterations: 0.030720958
# Current loss after 240 iterations: 0.0074918866
# Current loss after 250 iterations: 0.006617964
# Current loss after 260 iterations: 0.0032508203
# Current loss after 270 iterations: 0.0024487306
# Current loss after 280 iterations: 0.0022700657
# Current loss after 290 iterations: 0.0015720649
# Current loss after 300 iterations: 0.00084487395
# Current loss after 310 iterations: 0.0005731026
# Current loss after 320 iterations: 0.00048016003
# Current loss after 330 iterations: 0.00047306743
# Current loss after 340 iterations: 0.0004308392
# Current loss after 350 iterations: 0.00027010974
# Current loss after 360 iterations: 0.00025353115
# Current loss after 370 iterations: 0.00020392965
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.982056e-04
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 2.33e-10 ≰ 0.0e+00
#     |x - x'|/|x'|          = 2.70e-10 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 6.25e-04 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   130  (vs limit Inf)
#     Iterations:    176
#     f(x) calls:    639
#     ∇f(x) calls:   639

# %% [markdown]
# ## Plot The Prediction

# %%
NNsolution = predict(res2.minimizer)
# Trained on noisy data vs real solution
plot(solution.t, NNsolution', label = ["Learned x(t)" "Learned y(t)"])
scatter!(solution.t, X', label = ["True x(t)" "True y(t)"])

# %% [markdown]
# ## Prediction

# %%
function dudt_(u, p, t)
    x, y = u
    z = L(u, p)
    [p_[1]*x - p_[2]*y + z[1],
    p_[2]*x + p_[1]*y + z[2]]
end

# ODE problem
tspan2 = (0.0f0, 6.0f0)
prob_nn2 = ODEProblem(dudt_, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = 0.05);

# %% [markdown]
# ## Test The Prediction

# %%
tspan_test = (0.0f0, 6.0f0)
prob_test = ODEProblem(Hopf2D, u0, tspan_test, p_)
solution_test = solve(prob_test, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.05);

# %% [markdown]
# ## Plot Toghether True And Prediction
# ### Phase Space Plot

# %%
scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :])
plot!(Array(solution_test)[1, :], Array(solution_test)[2, :])

# %% [markdown]
# ## Plot $x(t)$ and $y(t)$

# %%
plot(sol_nn2)
scatter!(solution_test.t, Array(solution_test)[1, :])
scatter!(solution_test.t, Array(solution_test)[2, :])

# %% [markdown]
# -----------------------------------------
# -----------------------------------------
# -----------------------------------------

# %% [markdown]
# # SINDy Sparse Identification of Non-linear Dynamics
# ### Ideal derivatives:
# ### we take derivatives with respect to $t$ of $(x(t), y(t))$ both from the known solution and the solution to the trained UADE

# %%
DX = Array(solution(solution.t, Val{1})) 

prob_nn2 = ODEProblem(dudt_, u0, tspan, res2.minimizer)
_sol = solve(prob_nn2, Tsit5())

DX_ = Array(_sol(solution.t, Val{1}))

plot(solution.t, DX', label = ["True x'" " True y'"])
plot!(solution.t, DX_', label = ["Learned x'" "Learned y'"])

# %% [markdown]
# ## The learned derivatives

# %%
# Ideal data
L̄ = [p_[3]*(X[1,:].^(3) + X[1,:].*X[2,:].^(2))'; p_[4]*(X[2,:].*X[1,:].^(2) + X[2,:].^(3))']

# Neural network guess
L̂ = L(Xₙ, res2.minimizer)

scatter(solution.t, L̄')
plot!(solution.t, L̂')

# Plot the error
#scatter(abs.(L̄-L̂)', yaxis = :log)

# %% [markdown]
# ## Create a basis for the sparse identification

# %%
@variables u[1:2]

# Lots of polynomials
polys = Operation[1]

for i ∈ 1:5
    push!(polys, u[1]^i)
    push!(polys, u[2]^i)
    for j ∈ i:5
        if i != j
            push!(polys, (u[1]^i)*(u[2]^j))
            push!(polys, u[2]^i*u[1]^i)
        end
    end
end

# And some other stuff
h = [cos.(u)...; sin.(u)...; polys...]
basis = Basis(h, u)
# Out:
# 29 dimensional basis in ["u₁", "u₂"]

# %% [markdown]
# ## Optimizer for the algorithm

# %%
opt = SR3() #STRRidge(0.1)


# Create the thresholds which should be used in the search process
λ = exp10.(-7:0.1:3)

# Target function to choose the results from; x = L0 of coefficients and L2-Error of the model
g(x) = x[1] < 1 ? Inf : norm(x, 2)
# Out:
# g (generic function with 1 method)

# %% [markdown]
# ## Test on original data and without further knowledge (fail)

# %%
println("SINDy on full ideal, unavailable data")
Ψ = SINDy(Xₙ[:, :], DX[:, :], basis, λ, opt, g = g, maxiter = 10000) # Fail
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on full ideal, unavailable data
# Sparse Identification Result
# No. of Parameters : 2
# Active terms : 2
#    Equation 1 : 1
#    Equation 2 : 1
# Overall error (L2-Norm) : 1.7692074
#    Equation 1 : 1.0270998
#    Equation 2 : 0.7421075
# AICC :
#    Equation 1 : 2.2088325
#    Equation 2 : 3.5088341
#
# SR3{Float64,UnionAll}(0.19905358527674863, 1.0, ProximalOperators.NormL1) did not converge after 10000 iterations.
#
# 2 dimensional basis in ["u₁", "u₂"]
# du₁ = sin(u₂) * p₁
# du₂ = p₂ * u₁

# %% [markdown]
# ## Test on UADE derivative data

# %%
println("SINDy on learned, partial, available data")
Ψ = SINDy(Xₙ[:, 2:end], L̂[:, 2:end], basis, λ,  opt, g = g, maxiter = 10000, normalize = true, denoise = true)
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on learned, partial, available data
# Sparse Identification Result
# No. of Parameters : 2
# Active terms : 2
#    Equation 1 : 1
#    Equation 2 : 1
# Overall error (L2-Norm) : 1.9703789
#    Equation 1 : 1.42914
#    Equation 2 : 0.54123896
# AICC :
#    Equation 1 : 0.89603287
#    Equation 2 : 4.7799015
#
# SR3{Float64,UnionAll}(0.19905358527674863, 1.0, ProximalOperators.NormL1) converged after 1169 iterations.
#
# 2 dimensional basis in ["u₁", "u₂"]
# du₁ = u₁ ^ 3 * p₁
# du₂ = p₂ * u₂

# %%
opt = SR3()
Ψ = SINDy(Xₙ[:, 2:end], L̂[:, 2:end], basis, opt, maxiter = 100, n̂lize = true)
println(Ψ)
print_equations(Ψ)
# Out:
# Sparse Identification Result
# No. of Parameters : 3
# Active terms : 3
#    Equation 1 : 1
#    Equation 2 : 2
# Overall error (L2-Norm) : 2.130185
#    Equation 1 : 1.5749933
#    Equation 2 : 0.5551916
# AICC :
#    Equation 1 : 0.5073202
#    Equation 2 : 7.020435
#
# SR3{Float64,UnionAll}(0.1, 1.0, ProximalOperators.NormL1) did not converge after 100 iterations.
#
# 2 dimensional basis in ["u₁", "u₂"]
# du₁ = u₁ ^ 3 * p₁
# du₂ = sin(u₂) * p₂ + p₃ * u₂

# %% [markdown]
# ## Extract the parameters

# %%
p̂ = parameters(Ψ)
println("First parameter guess : $(p̂)")
# Out:
# First parameter guess : Float32[-0.58373535, -0.4695407]

# %% [markdown]
# ## Define the ODE with the new identified unknown term

# %%
unknown_sys = ODESystem(Ψ)
unknown_eq = ODEFunction(unknown_sys);

# %%
function dudt(du, u, p, t)
    # Add SINDy Term
    μ, ω, A1, A2 = p
    z = unknown_eq(u, [A1; A2], t)
    du[1] = μ*u[1] - ω*u[1] + z[1]
    du[2] = ω*u[2] + μ*u[2] + z[2]
end
# Out:
# dudt (generic function with 1 method)

# %% [markdown]
# ## Create the approximated problem and solution

# %%
ps = [p_[[1,2]]; p̂]
approximate_prob = ODEProblem(dudt, u0, tspan, ps)
approximate_solution = solve(approximate_prob, Tsit5(), saveat = 0.01)

# Plot
plot(solution, label = ["True x(t)" "True y(t)"])
scatter!(approximate_solution, label = ["Approx. x(t)" "Approx. y(t)"])
