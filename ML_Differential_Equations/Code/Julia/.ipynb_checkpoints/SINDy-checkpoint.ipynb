# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Generate the (noisy) training dataset from:
#
#
# ## $$
# \begin{aligned}
#   \dot{x} = \alpha x - \beta xy \\
#   \dot{y} =  \gamma xy - \delta y
# \end{aligned}
# $$

# %%
function LV(du, u, p, t)
    α, β, γ, δ = p
    du[1] = α*u[1] - β*u[2]*u[1]*u[1]
    du[2] = γ*u[1]*u[2]*u[2]  - δ*u[2]
end


p_ = Float32[1.3, 0.9, 0.8, 1.8]


# Define the experimental parameter

tspan = (0.0f0,3.0f0)
u0 = Float32[0.44249296,4.6280594]
p_ = Float32[1.3, 0.9, 0.8, 1.8]

prob = ODEProblem(LV, u0, tspan, p_)

solution = solve(prob, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.1)


X = Array(solution)

# Add noise to the data
println("Generate noisy data")
Xₙ = X + Float32(1e-3)*randn(eltype(X), size(X));
# Out:
# Generate noisy data

# %% [markdown]
# ## Plot the training dataset

# %%
#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])
plot(solution.t, Xₙ[1, :], xlabel = "t", label = "x")
plot!(solution.t, Xₙ[2, :], label = "y")

# %% [markdown]
# ## UADE

# %%
# Neural network

L = FastChain(FastDense(2, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 2))
p = initial_params(L)


# ODE

function dudt_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x + z[1],
    -p_[4]*y + z[2]]
end

# ODE problem
prob_nn = ODEProblem(dudt_, u0, tspan, p)
sol_nn = solve(prob_nn, Tsit5(), u0 = u0, p = p, saveat = 0.1);

# %% [markdown]
# ## Plot the untrained solution

# %%
plot(sol_nn, xlabel = "t")
#plot(Array(sol_nn)[1, :], Array(sol_nn)[2, :])

# %% [markdown]
# ## Loss function

# %%
# This function is used in the loss
function predict(θ)
    Array(solve(prob_nn, Vern7(), u0 = u0, p=θ, saveat = 0.1,
                         abstol=1e-6, reltol=1e-6,
                         sensealg = InterpolatingAdjoint(autojacvec=ReverseDiffVJP())))
end


# No regularisation right now
function loss(θ)
    pred = predict(θ)
    sum(abs2, Xₙ .- pred)
end


# Test
#loss(p)


const losses = []

# The callback function is cb(p,args...) where the arguments are the extra returns from the loss
callback(θ, l) = begin
    push!(losses, l)
    if length(losses)%10==0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")    
    end
    
    # The callback function must return a boolean where if true, then the optimizer will prematurely end the optimization
    false
end
# Out:
# callback (generic function with 1 method)

# %% [markdown]
# ## Training with ADAM

# %%
# Train with ADAM
res1 = DiffEqFlux.sciml_train(loss, p, ADAM(0.01), cb=callback, maxiters = 300)
# Out:
# loss: 125:   3%|██                                      |  ETA: 0:05:52
# Current loss after 10 iterations: 125.3096
# loss: 94:   7%|███                                      |  ETA: 0:04:28
# Current loss after 20 iterations: 94.03694
# loss: 84.3:  10%|████                                   |  ETA: 0:03:53
# Current loss after 30 iterations: 84.325966
# loss: 74.3:  13%|██████                                 |  ETA: 0:03:26
# Current loss after 40 iterations: 74.300766
# loss: 62.6:  17%|███████                                |  ETA: 0:03:12
# Current loss after 50 iterations: 62.588337
# loss: 48.6:  20%|████████                               |  ETA: 0:03:02
# Current loss after 60 iterations: 48.56823
# loss: 33.5:  23%|██████████                             |  ETA: 0:02:51
# Current loss after 70 iterations: 33.501774
# loss: 24:  27%|███████████                              |  ETA: 0:02:44m
# Current loss after 80 iterations: 24.018328
# loss: 21.1:  30%|████████████                           |  ETA: 0:02:33
# Current loss after 90 iterations: 21.10831
# loss: 17.9:  33%|█████████████                          |  ETA: 0:02:25
# Current loss after 100 iterations: 17.948479
# loss: 16.2:  37%|███████████████                        |  ETA: 0:02:17m
# Current loss after 110 iterations: 16.246367
# loss: 15:  40%|█████████████████                        |  ETA: 0:02:07
# Current loss after 120 iterations: 14.959873
# loss: 13.9:  43%|█████████████████                      |  ETA: 0:02:00
# Current loss after 130 iterations: 13.868674
# loss: 12.9:  47%|███████████████████                    |  ETA: 0:01:53
# Current loss after 140 iterations: 12.868501
# loss: 11.9:  50%|████████████████████                   |  ETA: 0:01:44
# Current loss after 150 iterations: 11.94474
# loss: 11.1:  53%|█████████████████████                  |  ETA: 0:01:38
# Current loss after 160 iterations: 11.103174
# loss: 10.4:  57%|███████████████████████                |  ETA: 0:01:31
# Current loss after 170 iterations: 10.370004
# loss: 9.75:  60%|████████████████████████               |  ETA: 0:01:24
# Current loss after 180 iterations: 9.746881
# loss: 9.22:  63%|█████████████████████████              |  ETA: 0:01:16
# Current loss after 190 iterations: 9.218779
# loss: 8.76:  67%|██████████████████████████             |  ETA: 0:01:09
# Current loss after 200 iterations: 8.763899
# loss: 8.36:  70%|████████████████████████████           |  ETA: 0:01:01
# Current loss after 210 iterations: 8.360966
# loss: 7.99:  73%|█████████████████████████████          |  ETA: 0:00:54
# Current loss after 220 iterations: 7.992892
# loss: 7.65:  77%|██████████████████████████████         |  ETA: 0:00:47
# Current loss after 230 iterations: 7.647944
# loss: 7.32:  80%|████████████████████████████████       |  ETA: 0:00:40
# Current loss after 240 iterations: 7.3190355
# loss: 7:  83%|███████████████████████████████████       |  ETA: 0:00:33
# Current loss after 250 iterations: 7.002603
# loss: 6.7:  87%|███████████████████████████████████     |  ETA: 0:00:27
# Current loss after 260 iterations: 6.6975274
# loss: 6.4:  90%|█████████████████████████████████████   |  ETA: 0:00:20
# Current loss after 270 iterations: 6.4043922
# loss: 6.12:  93%|█████████████████████████████████████  |  ETA: 0:00:13
# Current loss after 280 iterations: 6.1247993
# loss: 5.86:  97%|██████████████████████████████████████ |  ETA: 0:00:07
# Current loss after 290 iterations: 5.860785
# loss: 5.61: 100%|███████████████████████████████████████| Time: 0:03:16
# Current loss after 300 iterations: 5.614319
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     5.614319e+00
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   291  (vs limit Inf)
#     Iterations:    300
#     f(x) calls:    300
#     ∇f(x) calls:   300

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res1.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 1000)
# Out:
# Current loss after 310 iterations: 2.9978042
# Current loss after 320 iterations: 0.7972231
# Current loss after 330 iterations: 0.46603355
# Current loss after 340 iterations: 0.2750187
# Current loss after 350 iterations: 0.18097514
# Current loss after 360 iterations: 0.07169437
# Current loss after 370 iterations: 0.015533174
# Current loss after 380 iterations: 0.004710896
# Current loss after 390 iterations: 0.0014583424
# Current loss after 400 iterations: 0.000948603
# Current loss after 410 iterations: 0.0007310646
# Current loss after 420 iterations: 0.00041922127
# Current loss after 430 iterations: 0.0002961283
# Current loss after 440 iterations: 0.00020827947
# Current loss after 450 iterations: 0.00016393997
# Current loss after 460 iterations: 0.00015675813
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.566709e-04
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.64e-11 ≰ 0.0e+00
#     |x - x'|/|x'|          = 7.47e-12 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 7.38e-03 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   354  (vs limit Inf)
#     Iterations:    165
#     f(x) calls:    705
#     ∇f(x) calls:   705

# %% [markdown]
# ## Plot the loss

# %%
plot(losses, yaxis=:log, xlabel = "Iterations", ylabel = "Loss")

# %% [markdown]
# ## Plot the approximation and the original data

# %%
NNsolution = predict(res2.minimizer)
# Trained on noisy data vs real solution
plot(solution.t, NNsolution', label = ["Learned x(t)" "Learned y(t)"])
scatter!(solution.t, X', label = ["True x(t)" "True y(t)"])

# %% [markdown]
# ## Prediction

# %%
function dudt2_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x + z[1],
    -p_[4]*y + z[2]]
end

# ODE problem
tspan2 = (0.0f0, 5.0f0)
prob_nn2 = ODEProblem(dudt2_, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = 0.1);

# %% [markdown]
# ## Test the prediction

# %%
tspan_test = (0.0f0, 5.0f0)
prob_test = ODEProblem(LV, u0, tspan_test, p_)
solution_test = solve(prob_test, Vern7(), saveat = 0.05);

# %% [markdown]
# ## Plot Toghether True And Prediction
# ### Phase Space Plot

# %%
#scatter(Array(solution_test)[1, :], Array(solution_test)[2, :])
scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :], label = "Learned solution")
plot!(Array(solution_test)[1, :], Array(solution_test)[2, :], label = "True solution")

# %% [markdown]
# ## Plot $x(t)$ and $y(t)$

# %%
plot(sol_nn2)
scatter!(solution_test.t, Array(solution_test)[1, :], label = "true x(t)")
scatter!(solution_test.t, Array(solution_test)[2, :], label = "true y(t)")

# %% [markdown]
# # SINDy Sparse Identification of Non-linear Dynamics
# ### Ideal derivatives

# %%
DX = Array(solution(solution.t, Val{1}))

prob_nn2 = ODEProblem(dudt_, u0, tspan, res2.minimizer)
_sol = solve(prob_nn2, Tsit5())
DX_ = Array(_sol(solution.t, Val{1}))

plot(solution.t, DX', label = ["True x'" " True y'"])
plot!(solution.t, DX_', label = ["Learned x'" "Learned y'"])

# %% [markdown]
# ## The learned derivatives

# %%
# Ideal data
L̄ = [-p_[2]*(X[1,:].*X[2,:].*X[1,:])';p_[3]*(X[1,:].*X[2,:].*X[2,:])']
# Neural network guess
L̂ = L(Xₙ, res2.minimizer)

scatter(solution.t, L̄'[:, :])
plot!(solution.t, L̂'[:, :])





# Plot the error
#scatter(abs.(L̄-L̂)', yaxis = :log)

# %% [markdown]
# ## Create a basis for the sparse identification

# %%
@variables u[1:2]

# Lots of polynomials
polys = Operation[1]

for i ∈ 1:5
    push!(polys, u[1]^i)
    push!(polys, u[2]^i)
    for j ∈ i:5
        if i != j
            push!(polys, (u[1]^i)*(u[2]^j))
            push!(polys, u[2]^i*u[1]^i)
        end
    end
end

# And some other stuff
h = [cos.(u)...; sin.(u)...; polys...]
basis = Basis(h, u)
# Out:
# 29 dimensional basis in ["u₁", "u₂"]

# %% [markdown]
# ## Optimizer for the SINDy problem

# %%
opt = SR3()
#opt = STRRidge(0.1)
# Create the thresholds which should be used in the search process
λ = exp10.(-7:0.1:3)

# Target function to choose the results from; x = L0 of coefficients and L2-Error of the model
g(x) = x[1] < 1 ? Inf : norm(x, 2)
# Out:
# g (generic function with 1 method)

# %% [markdown]
# ## Test on original data and without further knowledge (fail)

# %%
println("SINDy on full ideal, unavailable data")
Ψ = SINDy(Xₙ[:, :], DX[:, :], basis, λ, opt, g = g, maxiter = 10000) # Fail
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on full ideal, unavailable data
# Sparse Identification Result
# No. of Parameters : 4
# Active terms : 4
#    Equation 1 : 2
#    Equation 2 : 2
# Overall error (L2-Norm) : 4.279847
#    Equation 1 : 1.0529509
#    Equation 2 : 3.226896
# AICC :
#    Equation 1 : 4.6825027
#    Equation 2 : 0.20280606
#
# SR3{Float64,UnionAll}(0.5, 1.0, ProximalOperators.NormL1) converged after 830 iterations.
#
# 2 dimensional basis in ["u₁", "u₂"]
# du₁ = u₁ ^ 2 * p₂ + p₁ * u₁
# du₂ = cos(u₁) * p₃ + cos(u₂) * p₄

# %% [markdown]
# ## Test on UADE derivative data

# %%
println("SINDy on learned, partial, available data")
Ψ = SINDy(Xₙ[:, 2:end], L̂[:, 2:end], basis, λ, opt, g=g, maxiter = 10000, normalize = true, denoise = true) # Succeed
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on learned, partial, available data
# Sparse Identification Result
# No. of Parameters : 6
# Active terms : 6
#    Equation 1 : 2
#    Equation 2 : 4
# Overall error (L2-Norm) : 1.8005755
#    Equation 1 : 0.7766989
#    Equation 2 : 1.0238767
# AICC :
#    Equation 1 : 5.9338875
#    Equation 2 : 10.405616
#
# SR3{Float64,UnionAll}(0.1, 1.0, ProximalOperators.NormL1) did not converge after 10000 iterations.
#
# 2 dimensional basis in ["u₁", "u₂"]
# du₁ = p₂ + sin(u₁) * p₁
# du₂ = u₂ ^ 2 * p₅ + p₃ * u₂ + u₁ ^ 3 * u₂ ^ 3 * p₆ + u₂ ^ 2 * p₄ * u₁

# %% [markdown]
# ## Extract the parameter

# %%
p̂ = parameters(Ψ)
println("First parameter guess : $(p̂)")
# Out:
# First parameter guess : Float32[-12.65252, -1.3816682, 13.05449, -0.46776992, -5.7894897, 0.09379758, -0.040798504, 0.34940523, 0.4267787, 0.0008502617, -0.04314747, 0.30728456, -0.7257962, 3.1051672]

# %% [markdown]
# ## Plot the identified function $\tilde{L}$ together with $\hat{L}$

# %%
L̃ = [[p̂[1] for i ∈ 1:length(solution.t)]'; p̂[4]*X[1,:]' + p̂[2].*X[2,:]' + (p̂[3].*X[2,:].^(2).*X[1,:])']

scatter(solution.t, unknown_eq)
plot!(solution.t, L̂'[:, :])
# Out:
# MethodError: no method matching getindex(::ODEFunction{true,DiffEqBase.EvalFunc{ModelingToolkit.var"#f#169"{ModelingToolkit.var"#540#541",ModelingToolkit.var"#542#543"}},UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Array{Symbol,1},Nothing}, ::Colon, ::Colon)
#
# Stacktrace:
#  [1] top-level scope at In[44]:3

# %% [markdown]
# ## Define the ODE with the new identified unknown term

# %%
unknown_sys = ODESystem(Ψ)
unknown_eq = ODEFunction(unknown_sys);

# %%
function dudt(du, u, p, t)
    # Add SINDy Term
    α, δ, β, γ = p
    z = unknown_eq(u, [β; γ], t)
    du[1] = α*u[1] + z[1]
    du[2] = -δ*u[2] + z[2]
end
# Out:
# dudt (generic function with 1 method)

# %% [markdown]
# ## Create the approximated problem and solution

# %%
ps = [p_[[1,4]]; p̂]
approximate_prob = ODEProblem(dudt, u0, tspan, ps)
approximate_solution = solve(approximate_prob, Tsit5(), saveat = 0.01)

# Plot
plot(solution, label = ["True x(t)" "True y(t)"])
plot!(approximate_solution, label = ["Approx. x(t)" "Approx. y(t)"])

# %% [markdown]
# ## Look at long term prediction

# %%
t_long = (0.0, 20.0)
approximate_prob = ODEProblem(dudt, u0, t_long, ps)
approximate_solution_long = solve(approximate_prob, Tsit5(), saveat = 0.1) # Using higher tolerances here results in exit of julia
scatter(approximate_solution_long, label = ["Approx. x(t)" "Approx. y(t)"])

true_prob = ODEProblem(LV, u0, t_long, p_)
true_solution_long = solve(true_prob, Tsit5(), saveat = approximate_solution_long.t)
plot!(true_solution_long, label = ["True x(t)" "True y(t)"])

# %% [markdown]
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------

# %% [markdown]
# ## How Sparse Identification work, simple example
# ########################################################

# %%
using DataDrivenDiffEq
using ModelingToolkit
using OrdinaryDiffEq

using LinearAlgebra
using Plots
gr()

# Create a test problem
function lorenz(u,p,t)
    x, y, z = u
    ẋ = 10.0*(y - x)
    ẏ = x*(28.0-z) - y
    ż = x*y - (8/3)*z
    return [ẋ, ẏ, ż]
end

u0 = [-8.0; 7.0; 27.0]
p = [10.0; -10.0; 28.0; -1.0; -1.0; 1.0; -8/3]

tspan = (0.0,100.0)

dt = 0.001

problem = ODEProblem(lorenz,u0,tspan)
solution = solve(problem, Tsit5(), saveat = dt, atol = 1e-7, rtol = 1e-8)

X = Array(solution)
DX = similar(X)
for (i, xi) in enumerate(eachcol(X))
    DX[:,i] = lorenz(xi, [], 0.0)
end
# Out:
# ┌ Info: Precompiling DataDrivenDiffEq [2445eb08-9709-466a-b3fc-47e12bd697a2]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DataDrivenDiffEq [2445eb08-9709-466a-b3fc-47e12bd697a2].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling CompilerSupportLibraries_jll [e66e0078-7015-5450-92f7-15fbd957f2ae]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing CompilerSupportLibraries_jll [e66e0078-7015-5450-92f7-15fbd957f2ae].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling SymbolicUtils [d1185830-fcd6-423d-90d6-eec64667417b]
# └ @ Base loading.jl:1260
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SymbolicUtils [d1185830-fcd6-423d-90d6-eec64667417b].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling DSP [717857b8-e6f2-59f4-9121-6e50c889abd2]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DSP [717857b8-e6f2-59f4-9121-6e50c889abd2].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling FFTW_jll [f5851436-0d7a-5f13-b9de-f02708fd171a]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FFTW_jll [f5851436-0d7a-5f13-b9de-f02708fd171a].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling Polynomials [f27b6e38-b328-58d1-80ce-0feddd5e7a45]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Polynomials [f27b6e38-b328-58d1-80ce-0feddd5e7a45].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling Intervals [d8418881-c3e1-53bb-8760-2df7ec849ed5]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Intervals [d8418881-c3e1-53bb-8760-2df7ec849ed5].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling TimeZones [f269a46b-ccf7-5d73-abea-4c690281aa53]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing TimeZones [f269a46b-ccf7-5d73-abea-4c690281aa53].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling EzXML [8f5d6c58-4d21-5cfd-889c-e3ad7ee6a615]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing EzXML [8f5d6c58-4d21-5cfd-889c-e3ad7ee6a615].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling XML2_jll [02c8fc9c-b97f-50b9-bbe4-9be30ff0a78a]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing XML2_jll [02c8fc9c-b97f-50b9-bbe4-9be30ff0a78a].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling Zlib_jll [83775a58-1f1d-513f-b197-d71354ab007a]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Zlib_jll [83775a58-1f1d-513f-b197-d71354ab007a].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling DataInterpolations [82cc6244-b520-54b8-b5a6-8a565e85f1d0]
# └ @ Base loading.jl:1260
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DataInterpolations [82cc6244-b520-54b8-b5a6-8a565e85f1d0].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling Optim [429524aa-4258-5aef-a3af-852621145aeb]
# └ @ Base loading.jl:1260
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Optim [429524aa-4258-5aef-a3af-852621145aeb].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c]
# └ @ Base loading.jl:1260
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# └ @ Base loading.jl:1260
# ┌ Warning: Module SpecialFunctions with build ID 3614175159976 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ForwardDiff [f6369f11-7733-5829-9624-2563aa707210].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling LineSearches [d3d80556-e9d4-5f37-9878-2ab0fcc64255]
# └ @ Base loading.jl:1260
# ┌ Warning: Module NLSolversBase with build ID 3813509490761 is missing from the cache.
# │ This may mean NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing LineSearches [d3d80556-e9d4-5f37-9878-2ab0fcc64255].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling ProximalOperators [a725b495-10eb-56fe-b38b-717eba820537]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ProximalOperators [a725b495-10eb-56fe-b38b-717eba820537].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling OSQP [ab2f91bb-94b4-55e3-9ba0-7f65df51de79]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing OSQP [ab2f91bb-94b4-55e3-9ba0-7f65df51de79].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling MathOptInterface [b8f27783-ece8-5eb3-8dc8-9495eed66fee]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing MathOptInterface [b8f27783-ece8-5eb3-8dc8-9495eed66fee].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling CodecBzip2 [523fee87-0ab8-5b00-afb7-3ecf72e48cfd]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing CodecBzip2 [523fee87-0ab8-5b00-afb7-3ecf72e48cfd].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling Bzip2_jll [6e34b625-4abd-537c-b88f-471c36dfa7a0]
# └ @ Base loading.jl:1260
# ┌ Warning: Module JLLWrappers with build ID 433247474461001 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Bzip2_jll [6e34b625-4abd-537c-b88f-471c36dfa7a0].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling CodecZlib [944b1d66-785c-5afd-91f1-9de20f533193]
# └ @ Base loading.jl:1260
# ┌ Warning: Module Zlib_jll with build ID 3743199369550 is missing from the cache.
# │ This may mean Zlib_jll [83775a58-1f1d-513f-b197-d71354ab007a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1016
# ┌ Info: Skipping precompilation since __precompile__(false). Importing CodecZlib [944b1d66-785c-5afd-91f1-9de20f533193].
# └ @ Base loading.jl:1033
# ┌ Info: Precompiling JSONSchema [7d188eb4-7ad8-530c-ae41-71a32a6d4692]
# └ @ Base loading.jl:1260

# %% [markdown]
# ## Now automatically discover the system that generated the data
# ################################################################

# %%
@variables x y z
u = Operation[x; y; z]
polys = Operation[]

for i ∈ 0:4
    for j ∈ 0:i
        for k ∈ 0:j
            push!(polys, u[1]^i*u[2]^j*u[3]^k)
            push!(polys, u[2]^i*u[3]^j*u[1]^k)
            push!(polys, u[3]^i*u[1]^j*u[2]^k)
        end
    end
end

basis = Basis(polys, u)

opt = STRRidge(0.1)
Ψ = SINDy(X, DX, basis, opt, maxiter = 100, normalize = true)
println(Ψ)
print_equations(Ψ)
get_error(Ψ)
# Out:
# Sparse Identification Result
# No. of Parameters : 7
# Active terms : 7
#    Equation 1 : 2
#    Equation 2 : 3
#    Equation 3 : 2
# Overall error (L2-Norm) : 5.465109513295757e-11
#    Equation 1 : 6.7202639134663155e-12
#    Equation 2 : 3.505423292198665e-11
#    Equation 3 : 1.2876598297504605e-11
# AICC :
#    Equation 1 : 106.90381476450982
#    Equation 2 : 102.29689898255064
#    Equation 3 : 104.30267815708592
#
# STRRidge{Float64}(0.1) converged after 2 iterations.
#
# 3 dimensional basis in ["x", "y", "z"]
# dx = p₁ * x + p₂ * y
# dy = p₃ * x + p₄ * y + p₅ * x * z
# dz = p₆ * z + p₇ * x * y
# 3-element Array{Float64,1}:
#  6.7202639134663155e-12
#  3.505423292198665e-11
#  1.2876598297504605e-11
