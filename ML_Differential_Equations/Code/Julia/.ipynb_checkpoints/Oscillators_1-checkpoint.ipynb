# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
using CUDA
using FixedPointNumbers
# Graphs 
using LightGraphs, SimpleWeightedGraphs
using GraphPlot, GraphRecipes
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Kuramoto oscillators
#
# ## $$
# \begin{aligned}
#   \dot{\theta_{i}} &= \omega_{i} + \sum_{j=0}^{N} a_{ij} \sin(\theta_{j} - \theta_{i})\\
# \end{aligned}
# $$

# %% [markdown]
# ## Define the graph

# %%
N = 20
G = SimpleGraph(N)

while true

    for i ∈ 1:N
        for j ∈ i:N
            if i != j && (i == j +1 || i == j-1 || i == j-2 || i == j-2) #rand(Float64) > 0.9999
                add_edge!(G, i, j)
            end
        end
    end
    
    if is_connected(G) == true
        break
    end
    
end


add_edge!(G, 1, 20)
add_edge!(G, 1, 19)
add_edge!(G, 2, 20)

gplot(G, layout=circular_layout, nodelabel=1:N)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9912550475536558cx, 0.055213456753867324cy), (0.9598014687414979cx, 0.2538035376210801cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9827254248593736cx, 0.05316567552200249cy), (0.8262915695155737cx, 0.5346195767704707cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9827254248593736cx, -0.0531656755220025cy), (0.8262915695155738cx, -0.5346195767704709cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9912550475536558cx, -0.055213456753867324cy), (0.9598014687414979cx, -0.2538035376210803cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9256776758312355cx, 0.35882577328697246cy), (0.8343958348388656cx, 0.5379764733804481cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9181983217877078cx, 0.35424241923432115cy), (0.620643446799919cx, 0.7637915695155738cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9510565162951536cx, 0.2531152949374527cy), (0.9510565162951536cx, -0.25311529493745294cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.7694885236228427cx, 0.6273137230445779cy), (0.6273137230445779cx, 0.7694885236228427cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.7637915695155738cx, 0.620643446799919cy), (0.35424241923432115cx, 0.9181983217877078cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5379764733804481cx, 0.8343958348388656cy), (0.35882577328697246cx, 0.9256776758312355cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.5346195767704708cx, -0.8262915695155737cy), (-0.053165675522002714cx, -0.9827254248593736cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.2538035376210802cx, -0.9598014687414979cy), (-0.055213456753867546cx, -0.9912550475536557cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.25311529493745283cx, -0.9510565162951535cy), (0.2531152949374525cx, -0.9510565162951536cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.0552134567538671cx, -0.9912550475536558cy), (0.2538035376210799cx, -0.9598014687414979cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.05316567552200228cx, -0.9827254248593738cy), (0.5346195767704705cx, -0.8262915695155739cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.35882577328697224cx, -0.9256776758312355cy), (0.5379764733804479cx, -0.8343958348388657cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.3542424192343209cx, -0.9181983217877078cy), (0.7637915695155737cx, -0.6206434467999192cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.6273137230445777cx, -0.7694885236228428cy), (0.7694885236228427cx, -0.6273137230445781 ...

# %% [markdown]
# ## Adjacency matrix

# %%
A = adjacency_matrix(G);

# %% [markdown]
# ## Extract the subgraph of known couplings

# %% [markdown]
# ## ODE

# %% [markdown]
# ### Initial conditions

# %%
#Random ω
#ω = 0.5*π*randn(Float32, (N,))

#ω all equal
ω = [π for i ∈ 1:N]

#Random initial phase
#u0 = abs.(π*randn(Float32, (N,)))

#Full circle
u0 = [(2*π/(N))*i for i ∈ 1:N];

#Soliton
#u0 = [1.5 for i ∈ 1:N/2]
#u0 = append!([0. for i ∈ 1:N/2], u0);

# %% [markdown]
# ### System

# %%
function Kuramoto(u, A, t)
    
    K = 3
    
    S = [sin(u[j] - u[i]) for i ∈ 1:N, j ∈ 1:N]    
    
    #ωₙ = ω +  5*Float32(1e-1)*randn(eltype(ω), size(ω))
    
    return [ω[j] + K*(1/(count(i->(i>0), Array(A[:, j]))))*(S*Array(A[:, j]))[j]   for j ∈ 1:N]
    
end


tspan = (0.0f0, 10.0f0)
prob = ODEProblem(Kuramoto, u0, tspan, A)
saveat = 0.1
solution = solve(prob, Vern7(), saveat = saveat) #abstol=1e-12, reltol=1e-12,



X = Array(solution)

# Add noise to the data
#println("Generate noisy data")
Xₙ = X #+ Float32(1e-4)*randn(eltype(X), size(X));

# %% [markdown]
# ## Animation
# ### Coloring

# %%
function nodecolor(θ)
    #color = RGBA(mod(θ, 2*π)/(5*π), mod(θ, 2*π)/(2*π), mod(θ, 2*π)/(5*π))
    return convert(RGB{N0f8}, HSV((360/(2*π))*mod(θ, 2*π), 1, 1))
end
# Out:
# nodecolor (generic function with 1 method)

# %%
anim = Plots.Animation()
#graphplot(G, markersize = 0.2, nodelabel=1:N, method=:circular, markercolor =:red);
#Plots.frame(anim)
for i ∈ 1:length(Xₙ[1, :])
    graphplot(G, markersize = 0.2, nodelabel=1:N, method=:circular, markercolor = nodecolor.(Xₙ[:, i]), size = (900, 500));
    Plots.frame(anim)
end


gif(anim, "sync.gif", fps = 10)
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\valpe\Documents\GitHub\ML_DynamicalSystems\Code\Julia\sync.gif
# └ @ Plots C:\Users\valpe\.julia\packages\Plots\uCh2y\src\animation.jl:104
# Plots.AnimatedGif("C:\\Users\\valpe\\Documents\\GitHub\\ML_DynamicalSystems\\Code\\Julia\\sync.gif")

# %% [markdown]
# ## Plot the solution

# %%
width = 900
height = 500

#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])

plot(solution.t, Xₙ[1, :], size = (width, height), label = false) #, label = "1", legend=:topleft,
for i ∈ 2:(N-1)
    plot!(solution.t, Xₙ[i, :], label = false) #, label = "$i"
end
plot!(solution.t, Xₙ[N, :], label = false) #, label = "$N"

# %% [markdown]
# ## UADE

# %%
# Neural network
L = Chain(Dense(N, 30, tanh), Dense(30, 15, tanh), Dense(15, 5, tanh), Dense(5, 5, tanh), Dense(5, 5, tanh), Dense(5, 15), Dense(15, 30, tanh), Dense(30, N, tanh))
loss(x,y) = sum(abs2, x .- y)
ps = Flux.params(L);

# %% [markdown]
# ## Training with ADAM

# %%
# Train with ADAM
for i in 1:100
    Flux.train!(loss, ps, [Xₙ[:, 50:90]], ADAM(0.1))
    println(loss(L(Xₙ[:, 1]),Xₙ[:, 1]))
end
# Out:
# 171.05886333272989
# 171.3100800100713
# 171.3107534705983
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326
# 171.31075486049326

# %%
ps
# Out:
# Params([Float32[0.34929642 0.20302166 … -0.24364837 0.102570765; -0.0734076 0.15044576 … -0.23303798 0.24023576; … ; 0.31348342 -0.07219603 … 0.08731002 -0.15101987; -0.11634012 -0.2579673 … 0.15958692 0.34378412], Float32[0.042869188, -0.031137666, 0.022049312, 0.019969318, 0.014887247, -0.033056304, -0.11418779, 0.011778225, 0.039659146, 0.014793626  …  -0.12184753, 0.021874405, 0.106005654, -0.037221204, -0.06907412, -0.071814045, 0.06749328, 0.08135398, 0.009975868, 0.0590009], Float32[0.05075789 0.018710794 … -0.26579848 -0.1966921; -0.36368105 -0.21330746 … -0.00025191507 -0.29864565; … ; 0.30522662 -0.018956339 … -0.14864706 -0.28273132; 0.56829435 -0.082396105 … -0.36099005 -0.22477593], Float32[-0.066868514, 0.02627801, -0.22661398, 0.15926862, 0.031340845, 0.020997697, -0.08296429, -0.13470697, -0.04244136, -0.1697044, 0.077796854, 0.118815355, -0.018607926, 0.025724955, -0.1535443], Float32[-0.23888181 0.31858605 … 0.29026085 0.05811928; 0.5510287 0.86645424 … 0.5378964 0.6969844; … ; -0.064074904 0.09409786 … 0.38835314 -0.12340146; 0.22850186 -0.20910624 … -0.03652219 0.22062697], Float32[0.06962551, -0.3661246, 0.005241602, 0.04165619, -0.083574325], Float32[0.13280171 0.23296852 … -0.10190878 -0.030525785; -0.47088566 0.5473821 … -0.34615222 0.3068654; … ; -0.60243934 0.7133957 … -0.3041088 -0.036157064; 0.32805172 -0.5809076 … -0.26190782 -0.6198273], Float32[-0.139689, -0.00025140232, -0.15940517, -0.120157294, 0.13809516], Float32[0.88840723 0.51954156 … 0.010658003 -0.7538238; 0.35821596 0.55305684 … -0.08230852 -0.69972515; … ; -0.6651878 -0.3729072 … -0.510952 -0.42523262; -0.7606443 0.32933995 … 0.5646238 -0.1368887], Float32[-0.13972911, -0.020739578, 0.118688524, 0.000243917, 0.13995178], Float32[0.06743959 -0.33119795 … -0.5684282 0.09436618; -0.39475575 -0.5796286 … 0.033043724 0.1108324; … ; 0.24481888 -0.113427766 … 0.020335102 0.019376252; -0.49523383 -0.43221986 … -0.07907035 0.44891733], Float32[0.15996854, 0.18002918, -0.18003611, -0.020059776, -0.079971895, -0.13992131, 0.1599669, 0.039971277, 0.22016694, -0.17997164, -0.11997861, -0.22009124, -0.1801827, 0.040076997, 0.15997878], Float32[0.7308597 0.50319916 … -0.6843727 0.5160385; -0.36238447 -0.21830778 … 0.19527352 -0.28324816; … ; -0.39591923 -0.37709016 … 0.4049441 -0.036027167; 0.14893486 0.34869137 … -0.7273587 0.6397279], Float32[0.42757225, -0.15307008, 0.49500442, 0.099506505, 0.2956532, -0.17797504, 0.1794576, -0.19608426, -0.28839287, -0.4848305  …  0.17996152, 0.19855231, -0.42767352, 0.2953325, -0.13912126, -0.15387902, -0.09999154, -0.4578458, -0.29294798, 0.38254616], Float32[0.039748114 0.22728568 … -0.19161195 0.35198265; -0.14402752 0.20591955 … 0.21859206 0.029657284; … ; 0.3671768 -0.31633046 … -0.27332166 0.34613696; 0.04430807 -0.40883335 … -0.13980472 0.34084812], Float32[0.11970812, 0.07363155, 0.093685746, 0.41816327, 0.35458595, 0.37879884, 0.39949334, 0.32968894, 0.35985345, 0.31991065, 0.3399402, 0.31994325, 0.33995843, 0.3099728, 0.3199817, 0.3299863, 0.3099927, 0.2999881, 0.30999303, 0.2699923]])

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res1.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 50)
# Out:
# Current loss after 110 iterations: 0.19271168
# Current loss after 120 iterations: 0.10212062
#  * Status: failure
#
#  * Candidate solution
#     Final objective value:     7.441945e-02
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 6.31e-03 ≰ 0.0e+00
#     |x - x'|/|x'|          = 1.25e-02 ≰ 0.0e+00
#     |f(x) - f(x')|         = 5.00e-03 ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 6.72e-02 ≰ 0.0e+00
#     |g(x)|                 = 2.34e-01 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   39  (vs limit Inf)
#     Iterations:    23
#     f(x) calls:    50
#     ∇f(x) calls:   50

# %% [markdown]
# ## Plot the loss

# %%
plot(losses, yaxis=:log)

# %% [markdown]
# ## Plot the prediction

# %%
NNsolution = predict(res1.minimizer)
# Trained on noisy data vs real solution
plot(solution.t, NNsolution', label = ["Learned x(t)" "Learned y(t)"], size = (width, height))
scatter!(solution.t, X', label = ["True x(t)" "True y(t)"])

# %% [markdown]
# ## Prediction

# %%
function dudt_2(u, p, t)
    x1, x2, x3, x4, x5, x6, x7, x8, x9 = u
    z = L(u,p)
    [z[1],
    z[2],
    z[3],
    z[4],
    z[5],
    z[6],
    z[7],
    z[8],
    z[9]]
end

# ODE problem
tspan2 = (0.0f0, 6.0f0)
prob_nn2 = ODEProblem(dudt_2, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = saveat);

# %% [markdown]
# ## Test the prediction

# %%
prob_test = ODEProblem(Kuramoto, u0, tspan2, p_)
solution_test = solve(prob_test, Vern7(), saveat = saveat);

# %% [markdown]
# ## Prot together true and prediction

# %% [markdown]
# ## Plot $q(t)$ and $p(t)$

# %%
plot(sol_nn2, label = ["learned θ₁" "learned θ₂" "learned θ₃" "learned θ₄" "learned θ₅" "learned θ₆" "learned θ₇" "learned θ₈" "learned θ₉"], size = (width, height))
scatter!(solution_test.t, Array(solution_test)[1, :], label = "true θ₁")
scatter!(solution_test.t, Array(solution_test)[2, :], label = "true θ₂")
scatter!(solution_test.t, Array(solution_test)[3, :], label = "true θ₃")
scatter!(solution_test.t, Array(solution_test)[4, :], label = "true θ₄")
scatter!(solution_test.t, Array(solution_test)[5, :], label = "true θ₅")
scatter!(solution_test.t, Array(solution_test)[6, :], label = "true θ₆")
scatter!(solution_test.t, Array(solution_test)[7, :], label = "true θ₇")
scatter!(solution_test.t, Array(solution_test)[8, :], label = "true θ₈")
scatter!(solution_test.t, Array(solution_test)[9, :], label = "true θ₉")

# %% [markdown]
# --------------------------------------------------------
# --------------------------------------------------------
# --------------------------------------------------------

# %% [markdown]
# # SINDy Sparse Identification of Non-linear Dynamics
# ### Ideal derivatives:
# ### we take derivatives with respect to $t$ of $(x(t), y(t))$ both from the known solution and the solution to the trained UADE

# %%
DX = Array(solution(solution.t, Val{1})) 

prob_nn2 = ODEProblem(dudt_2, u0, tspan, res2.minimizer)
_sol = solve(prob_nn2, Tsit5())

DX_ = Array(_sol(solution.t, Val{1}))

plot(solution.t, DX', label = ["learned θ₁" "learned θ₂" "learned θ₃" "learned θ₄" "learned θ₅" "learned θ₆" "learned θ₇" "learned θ₈" "learned θ₉"])
plot!(solution.t, DX_', label = ["true θ₁" "true θ₂" "true θ₃" "true θ₄" "true θ₅" "true θ₆" "true θ₇" "true θ₈" "true θ₉"])

# %% [markdown]
# ## The learned derivatives

# %%
# Ideal data
#L̄ = [(Xₙ[2,:]/(p_[1]*p_[2]^(2)))'; -p_[1]*p_[2]*p_[3]*sin.(Xₙ[1,:]')]

# Neural network guess
L̂ = L(Xₙ, res2.minimizer)

#scatter(solution.t, L̄', label = ["L̄₁" "L̄₂" "L̄₃" "L̄₄" "L̄₅" "L̄₆" "L̄₇" "L̄₈" "L̄₉"])
plot(solution.t, L̂', label = ["L̂₁" "L̂₂" "L̂₃" "L̂₄" "L̂₅" "L̂₆" "L̂₇" "L̂₈" "L̂₉"])


#savefig("UADE.png")

# Plot the error
#scatter(abs.(L̄-L̂)', yaxis = :log)

# %% [markdown]
# ## Create a basis for the sparse identification

# %%
@variables u[1:9]

# Lots of polynomials
ops = Operation[1]

for i ∈ 1:9
    for j ∈ i:9
        if i != j
            push!(ops, sin(u[i] - u[j]))
        end
    end
end

# And some other stuff
h = [ops...]
basis = Basis(h, u)
# Out:
# 37 dimensional basis in ["u₁", "u₂", "u₃", "u₄", "u₅", "u₆", "u₇", "u₈", "u₉"]

# %% [markdown]
# ## Optimizer for the algorithm

# %%
opt = SR3() 
#opt = STRRidge(0.1)


# Create the thresholds which should be used in the search process
λ = exp10.(-5:0.1:5)

# Target function to choose the results from; x = L0 of coefficients and L2-Error of the model
g(x) = x[1] < 1 ? Inf : norm(x, 2)

#Suggestion from AlCap23
#g(x) = x[1] < 1 ? Inf : norm([0.1; 10.0] .* x, 2)
# Out:
# g (generic function with 1 method)

# %% [markdown]
# ## Test on original data and without further knowledge (fail)

# %%
println("SINDy on full ideal, unavailable data")
Ψ = SINDy(Xₙ[:, :], DX[:, :], basis, λ, opt, g = g, maxiter = 50000) # Fail
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on full ideal, unavailable data
# Sparse Identification Result
# No. of Parameters : 14
# Active terms : 14
#    Equation 1 : 1
#    Equation 2 : 1
#    Equation 3 : 1
#    Equation 4 : 2
#    Equation 5 : 2
#    Equation 6 : 1
#    Equation 7 : 4
#    Equation 8 : 1
#    Equation 9 : 1
# Overall error (L2-Norm) : 16.231901
#    Equation 1 : 0.111663446
#    Equation 2 : 1.9661889
#    Equation 3 : 0.099619135
#    Equation 4 : 1.1432382
#    Equation 5 : 2.862074
#    Equation 6 : 0.35740933
#    Equation 7 : 1.7041503
#    Equation 8 : 2.0595655
#    Equation 9 : 5.9279923
# AICC :
#    Equation 1 : 10.859973
#    Equation 2 : -0.6134793
#    Equation 3 : 11.316513
#    Equation 4 : 3.647747
#    Equation 5 : -0.02297971
#    Equation 6 : 6.2064033
#    Equation 7 : 6.3328495
#    Equation 8 : -0.799071
#    Equation 9 : -5.0278335
#
# SR3{Float64,UnionAll}(0.3154786722400966, 1.0, ProximalOperators.NormL1) converged after 7956 iterations.
#
# 9 dimensional basis in ["u₁", "u₂", "u₃", "u₄", "u₅", "u₆", "u₇", "u₈", "u₉"]
# du₁ = p₁ * sin(-1u₃ + u₁)
# du₂ = p₂ * sin(-1u₆ + u₁)
# du₃ = p₃ * sin(-1u₃ + u₂)
# du₄ = p₄ * sin(-1u₇ + u₆) + p₅ * sin(-1u₉ + u₈)
# du₅ = p₆ * sin(-1u₅ + u₂) + p₇ * sin(-1u₅ + u₃)
# du₆ = p₈ * sin(-1u₆ + u₃)
# du₇ = p₁₀ * sin(-1u₇ + u₄) + p₁₁ * sin(-1u₆ + u₅) + p₁₂ * sin(-1u₉ + u₆) + p₉ * sin(-1u₇ + u₂)
# du₈ = p₁₃ * sin(-1u₈ + u₆)
# du₉ = p₁₄ * sin(-1u₈ + u₆)

# %% [markdown]
# ## Test on UADE derivative data

# %%
println("SINDy on learned, partial, available data")
Ψ = SINDy(Xₙ[:, 2:end], L̂[:, 2:end], basis, λ,  opt, g = g, maxiter = 50000, normalize = true, denoise = true)
println(Ψ)
print_equations(Ψ)
# Out:
# SINDy on learned, partial, available data
# Sparse Identification Result
# No. of Parameters : 13
# Active terms : 13
#    Equation 1 : 1
#    Equation 2 : 1
#    Equation 3 : 1
#    Equation 4 : 2
#    Equation 5 : 2
#    Equation 6 : 1
#    Equation 7 : 1
#    Equation 8 : 2
#    Equation 9 : 2
# Overall error (L2-Norm) : 13.355528
#    Equation 1 : 2.5896833
#    Equation 2 : 1.1707206
#    Equation 3 : 1.2283653
#    Equation 4 : 0.38742688
#    Equation 5 : 0.5047346
#    Equation 6 : 0.8136021
#    Equation 7 : 3.3593397
#    Equation 8 : 1.4578966
#    Equation 9 : 1.8437593
# AICC :
#    Equation 1 : -1.6186426
#    Equation 2 : 1.5570223
#    Equation 3 : 1.3647628
#    Equation 4 : 8.173865
#    Equation 5 : 7.1158423
#    Equation 6 : 3.0126357
#    Equation 7 : -2.6594777
#    Equation 8 : 2.8729734
#    Equation 9 : 1.9337261
#
# SR3{Float64,UnionAll}(0.19905358527674863, 1.0, ProximalOperators.NormL1) converged after 16866 iterations.
#
# 9 dimensional basis in ["u₁", "u₂", "u₃", "u₄", "u₅", "u₆", "u₇", "u₈", "u₉"]
# du₁ = p₁ * sin(-1u₂ + u₁)
# du₂ = p₂ * sin(-1u₈ + u₅)
# du₃ = p₃ * sin(-1u₈ + u₄)
# du₄ = p₄ * sin(-1u₅ + u₁) + p₅ * sin(-1u₆ + u₄)
# du₅ = p₆ * sin(-1u₃ + u₂) + p₇ * sin(-1u₅ + u₂)
# du₆ = p₈ * sin(-1u₇ + u₅)
# du₇ = p₉ * sin(-1u₆ + u₁)
# du₈ = p₁₀ * sin(-1u₄ + u₃) + p₁₁ * sin(-1u₉ + u₅)
# du₉ = p₁₂ * sin(-1u₆ + u₃) + p₁₃ * sin(-1u₉ + u₄)

# %% [markdown]
# ## Extract the parameters

# %%
p̂ = parameters(Ψ)
println("First parameter guess : $(p̂)")
# Out:
# First parameter guess : Float32[-0.96555394, -0.76013964, 0.98906356, 0.15201946, 1.1698142, 0.2386253, 0.91897637, 0.94067514, 0.5393447, 0.23502429, 0.14268371, 0.2948936, 0.6306754, 0.24144149]

# %% [markdown]
# ## Define the ODE with the new identified unknown term

# %%
unknown_sys = ODESystem(Ψ)
unknown_eq = ODEFunction(unknown_sys);

# %%
function dudt(du, u, p, t)
    p1, p2, p3, p4, p5, p6, p7, p8, p9 = p
    z = unknown_eq(u, [p1; p2; p3; p4; p5; p6; p7; p8; p9], t)
    du[1] = z[1]
    du[2] = z[2]
    du[3] = z[3]
    du[4] = z[4]
    du[5] = z[5]
    du[6] = z[6]
    du[7] = z[7]
    du[8] = z[8]
    du[9] = z[9]
end
# Out:
# dudt (generic function with 1 method)

# %% [markdown]
# ## Create the approximated problem and solution

# %%
#ps = [p_[[1,2]]; p̂]
tspan = (0.0f0, 1.0f0)
approximate_prob = ODEProblem(dudt, u0, tspan, p̂)
approximate_solution = solve(approximate_prob, Tsit5(), saveat = 0.1)

# Plot
plot(solution_test, label = ["True x(t)" "True y(t)"])
scatter!(approximate_solution, label = ["Approx. x(t)" "Approx. y(t)"])
# Out:
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase C:\Users\valpe\.julia\packages\DiffEqBase\3iigH\src\integrator_interface.jl:349

# %%
x = [i*i/5 for i in 1:10]

anim = @animate for i ∈ 1:10
    plot(i.*x)
end

#gif(anim, "anim_fps15.gif", fps = 15)
# Out:
# Animation("C:\\Users\\valpe\\AppData\\Local\\Temp\\jl_R0I0tA", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"])

# %%
using Plots
