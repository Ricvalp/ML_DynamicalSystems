# %%
import tensorflow as tf
import keras
from keras import backend as bk
import timeit

import sys
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

from scipy.integrate import ode
import math as mt
import numpy as np
import matplotlib.pyplot as plt
import random as rdm
import time
from datetime import datetime
import matplotlib.animation as animation
from IPython.display import display, clear_output

physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
##############################################################################################################
###################################### Linear Modules ########################################################
##############################################################################################################


class linear_module_up:
    
    def __init__(self):
        self.a11 = tf.Variable(rdm.choice([-1,1])*rdm.random()) #tf.constant(rdm.random()) 
    
    def run(self, X):
        L = tf.concat([[[1., self.a11]], [[0., 1.]]], 0)
        return tf.matmul(L, X)
    
    def Variables(self):
        return [self.a11]
    
    def grad_des(self, grad, rate):
        self.a11 = tf.Variable(self.a11 - rate*grad)

        
class linear_module_low:
    
    def __init__(self):
        self.a11 = tf.constant(rdm.choice([-1,1])*rdm.random()) #tf.Variable(rdm.random())
    
    def run(self, X):
        L = tf.concat([[[1., 0.]], [[self.a11, 1.]]], 0)
        return tf.matmul(L, X)
    
    def Variables(self):
        return [self.a11]
    
    def grad_des(self, grad, rate):
        self.a11 = tf.Variable(self.a11 - rate*grad)

##############################################################################################################
###################################### Activation Modules ####################################################
##############################################################################################################

class activation_module_up:
    
    def __init__(self):
        self.a1 = tf.constant(rdm.choice([-1,1])*rdm.random()) #tf.Variable(rdm.random())        
    
    def run(self, X):
                    
        return  tf.reshape(tf.stack([X[0] + self.a1*tf.math.sigmoid(X[1]), X[1]]),(2,1))

    
    def Variables(self):
        return [self.a1]
    
    def grad_des(self, grad, rate):

        self.a1 = tf.Variable(self.a1 - rate*grad)

        
class activation_module_low:
    
    def __init__(self):
        self.a1 = tf.constant(rdm.choice([-1,1])*rdm.random()) #tf.Variable(rdm.random())
        
    
    def run(self, X):

        return tf.reshape(tf.stack([X[0], X[1] + self.a1*tf.math.sigmoid(X[0])]),(2,1))

    
    def Variables(self):
        return [self.a1]
    
    def grad_des(self, grad, rate):

        self.a1 = tf.Variable(self.a1 - rate*grad)

# %% [markdown]
# ### Reversible SympNet: $$ \phi_{t = \Delta t} = L_{1}L_{2}  A_{1}  L_{3}L_{4}L_{3}  A_{2}  L_{2}L_{1}$$

# %%
class Rev_SympNet:

    def __init__(self):
        
        self.L1 = linear_module_up()
        self.L2 = linear_module_low()
        
        self.A1 = activation_module_up()
        
        self.L3 = linear_module_up()
        self.L4 = linear_module_low()


    def run(self, X):
        
        boom = self.L1.run(X)
        boom1 = self.L2.run(boom)
        
        boom2 = self.A1.run(boom1)
        
        boom3 = self.L3.run(boom2)
        boom4 = self.L4.run(boom3)
        boom5 = self.L3.run(boom4)
        
        boom6 = self.A1.run(boom5)
        
        boom7 = self.L3.run(boom6)
        boom8 = self.L4.run(boom7)
        boom9 = self.L3.run(boom8)
        
        boom7 = self.L2.run(boom6)
        boom8 = self.L1.run(boom7)

        return boom8
    
    
    ##################################### Loss function ##########################
    
    def get_loss(self, X, X_target):
        
        loss = 0
        for i,j in zip(X,X_target):
            loss = loss + tf.norm(self.run(i) - j)**2
                    
        return loss/(len(X)*2)

    
    ################################### get gradient ############################
    
    def get_grad(self, X, X_target):
        
        with tf.GradientTape() as tape:
            
            tape.watch(self.L1.Variables())
            tape.watch(self.L2.Variables())
            
            tape.watch(self.A1.Variables())

            tape.watch(self.L3.Variables())
            tape.watch(self.L4.Variables())
            
            
            L = self.get_loss(X, X_target)
            
            g = tape.gradient(L, [self.L1.Variables(), self.L2.Variables(), self.A1.Variables(), self.L3.Variables(), self.L4.Variables()])
        
        return [item for sublist in g for item in sublist]

    ################################## perform gradient descent ##################
    
    def network_learn(self, X, X_target, rate):
        
        g = self.get_grad( X, X_target)
                
        self.L1.grad_des(g[0], rate)
        self.L2.grad_des(g[1], rate)
        
        self.A1.grad_des(g[2], rate)
        
        self.L3.grad_des(g[3], rate)
        self.L4.grad_des(g[4], rate)

# %% [markdown]
# ### Non-Reversible SympNet: $$ \phi_{t = \Delta t} = L_{1}L_{2}  A_{1}  L_{3}L_{4}L_{3}  A_{2}$$

# %%
class NonRev_SympNet:

    def __init__(self):
        
        self.L1 = linear_module_up()
        self.L2 = linear_module_low()
        
        self.A1 = activation_module_up()
        
        self.L3 = linear_module_up()
        self.L4 = linear_module_low()


    def run(self, X):
        
        boom = self.L1.run(X)
        boom1 = self.L2.run(boom)
        
        boom2 = self.A1.run(boom1)
        
        boom3 = self.L3.run(boom2)
        boom4 = self.L4.run(boom3)
        boom5 = self.L3.run(boom4)
        
        boom6 = self.A1.run(boom5)
        
        #boom7 = self.L3.run(boom6)
        #boom8 = self.L4.run(boom7)
        #boom9 = self.L3.run(boom8)
        
        #boom7 = self.L2.run(boom6)
        #boom8 = self.L1.run(boom7)

        return boom6
    
    
    ##################################### Loss function ##########################
    
    def get_loss(self, X, X_target):
        
        loss = 0
        for i,j in zip(X,X_target):
            loss = loss + tf.norm(self.run(i) - j)**2
                    
        return loss/(len(X)*2)

    
    ################################### get gradient ############################
    
    def get_grad(self, X, X_target):
        
        with tf.GradientTape() as tape:
            
            tape.watch(self.L1.Variables())
            tape.watch(self.L2.Variables())
            
            tape.watch(self.A1.Variables())

            tape.watch(self.L3.Variables())
            tape.watch(self.L4.Variables())
            
            
            L = self.get_loss(X, X_target)
            
            g = tape.gradient(L, [self.L1.Variables(), self.L2.Variables(), self.A1.Variables(), self.L3.Variables(), self.L4.Variables()])
        
        return [item for sublist in g for item in sublist]

    ################################## perform gradient descent ##################
    
    def network_learn(self, X, X_target, rate):
        
        g = self.get_grad( X, X_target)
                
        self.L1.grad_des(g[0], rate)
        self.L2.grad_des(g[1], rate)
        
        self.A1.grad_des(g[2], rate)
        
        self.L3.grad_des(g[3], rate)
        self.L4.grad_des(g[4], rate)

# %% [markdown]
# ### Training Dataset

# %%
def leapfrog(q0, p0, Δt, N):
    q = [q0]
    p = [p0]
    p̄ = []
    for i in range(N):
        p̄.append(p[-1] - 0.5*Δt*mt.sin(q[-1]))
        q.append(q[-1] + Δt*p̄[-1])
        p.append(p̄[-1] - 0.5*Δt*mt.sin(q[-1]))
    
    X = []
    for i,j in zip(p,q):
        X.append(tf.constant([[i],[j]]))
    return X[0:len(X)-1], X[1:]

def plot_true_tr(leapfrog, q0, p0, Δt, N):
    X = leapfrog(q0, p0, Δt, N)[0]
    q = []
    p = []
    for i in range(len(X)):
        q.append(X[i][0].numpy()[0])
        p.append(X[i][1].numpy()[0])
    plt.plot(p, q)

# %%
q0 = 1.
p0 = 0.
Δt = 0.1
N = 40

X = leapfrog(q0, p0, Δt, N)
plot_true_tr(leapfrog, q0, p0, Δt, N)

# %% [markdown]
# ### Training

# %%
Model_Rev = Rev_SympNet()
Model_NonRev = NonRev_SympNet()
losses = []

# %%
N_train = 1000
rate = 0.01

start_time = time.time()

for i in range(N_train):
    if i%10==0:
        print(Model_Rev.get_loss(X[0], X[1]))
    Model_Rev.network_learn(X[0], X[1], rate)
    losses.append(Model_Rev.get_loss(X[0],X[1]))

print("running time : %s seconds" % (time.time() - start_time))


start_time = time.time()

for i in range(N_train):
    if i%10==0:
        print(Model_NonRev.get_loss(X[0], X[1]))
    Model_NonRev.network_learn(X[0], X[1], rate)
    losses.append(Model_NonRev.get_loss(X[0],X[1]))

print("running time : %s seconds" % (time.time() - start_time))
# Out:
# tf.Tensor(0.0010061612, shape=(), dtype=float32)
# tf.Tensor(0.00084110524, shape=(), dtype=float32)
# tf.Tensor(0.0007031821, shape=(), dtype=float32)
# tf.Tensor(0.00058794074, shape=(), dtype=float32)
# tf.Tensor(0.0004916572, shape=(), dtype=float32)
# tf.Tensor(0.00041122077, shape=(), dtype=float32)
# tf.Tensor(0.0003440258, shape=(), dtype=float32)
# tf.Tensor(0.0002878966, shape=(), dtype=float32)
# tf.Tensor(0.00024101243, shape=(), dtype=float32)
# tf.Tensor(0.00020185302, shape=(), dtype=float32)
# tf.Tensor(0.00016914637, shape=(), dtype=float32)
# tf.Tensor(0.00014183015, shape=(), dtype=float32)
# tf.Tensor(0.00011901718, shape=(), dtype=float32)
# tf.Tensor(9.996516e-05, shape=(), dtype=float32)
# tf.Tensor(8.405499e-05, shape=(), dtype=float32)
# tf.Tensor(7.076837e-05, shape=(), dtype=float32)
# tf.Tensor(5.967268e-05, shape=(), dtype=float32)
# tf.Tensor(5.0407434e-05, shape=(), dtype=float32)
# tf.Tensor(4.2670417e-05, shape=(), dtype=float32)
# tf.Tensor(3.6209844e-05, shape=(), dtype=float32)
# tf.Tensor(3.081495e-05, shape=(), dtype=float32)
# tf.Tensor(2.6310063e-05, shape=(), dtype=float32)
# tf.Tensor(2.2548666e-05, shape=(), dtype=float32)
# tf.Tensor(1.940785e-05, shape=(), dtype=float32)
# tf.Tensor(1.6785307e-05, shape=(), dtype=float32)
# tf.Tensor(1.4595465e-05, shape=(), dtype=float32)
# tf.Tensor(1.2766985e-05, shape=(), dtype=float32)
# tf.Tensor(1.1240321e-05, shape=(), dtype=float32)
# tf.Tensor(9.965523e-06, shape=(), dtype=float32)
# tf.Tensor(8.901201e-06, shape=(), dtype=float32)
# tf.Tensor(8.012328e-06, shape=(), dtype=float32)
# tf.Tensor(7.2704097e-06, shape=(), dtype=float32)
# tf.Tensor(6.6507664e-06, shape=(), dtype=float32)
# tf.Tensor(6.1334526e-06, shape=(), dtype=float32)
# tf.Tensor(5.7014963e-06, shape=(), dtype=float32)
# tf.Tensor(5.340901e-06, shape=(), dtype=float32)
# tf.Tensor(5.039743e-06, shape=(), dtype=float32)
# tf.Tensor(4.7883213e-06, shape=(), dtype=float32)
# tf.Tensor(4.578468e-06, shape=(), dtype=float32)
# tf.Tensor(4.403146e-06, shape=(), dtype=float32)
# tf.Tensor(4.256802e-06, shape=(), dtype=float32)
# tf.Tensor(4.134621e-06, shape=(), dtype=float32)
# tf.Tensor(4.032619e-06, shape=(), dtype=float32)
# tf.Tensor(3.9474357e-06, shape=(), dtype=float32)
# tf.Tensor(3.8762855e-06, shape=(), dtype=float32)
# tf.Tensor(3.8169146e-06, shape=(), dtype=float32)
# tf.Tensor(3.7673435e-06, shape=(), dtype=float32)
# tf.Tensor(3.7259692e-06, shape=(), dtype=float32)
# tf.Tensor(3.6914262e-06, shape=(), dtype=float32)
# tf.Tensor(3.6625545e-06, shape=(), dtype=float32)
# tf.Tensor(3.6384306e-06, shape=(), dtype=float32)
# tf.Tensor(3.618333e-06, shape=(), dtype=float32)
# tf.Tensor(3.6015565e-06, shape=(), dtype=float32)
# tf.Tensor(3.5874968e-06, shape=(), dtype=float32)
# tf.Tensor(3.5757523e-06, shape=(), dtype=float32)
# tf.Tensor(3.566033e-06, shape=(), dtype=float32)
# tf.Tensor(3.557857e-06, shape=(), dtype=float32)
# tf.Tensor(3.551087e-06, shape=(), dtype=float32)
# tf.Tensor(3.5453363e-06, shape=(), dtype=float32)
# tf.Tensor(3.5406138e-06, shape=(), dtype=float32)
# tf.Tensor(3.5366309e-06, shape=(), dtype=float32)
# tf.Tensor(3.5333e-06, shape=(), dtype=float32)
# tf.Tensor(3.5305231e-06, shape=(), dtype=float32)
# tf.Tensor(3.5282324e-06, shape=(), dtype=float32)
# tf.Tensor(3.5263165e-06, shape=(), dtype=float32)
# tf.Tensor(3.524714e-06, shape=(), dtype=float32)
# tf.Tensor(3.5233375e-06, shape=(), dtype=float32)
# tf.Tensor(3.5222213e-06, shape=(), dtype=float32)
# tf.Tensor(3.5213404e-06, shape=(), dtype=float32)
# tf.Tensor(3.5205278e-06, shape=(), dtype=float32)
# tf.Tensor(3.5198664e-06, shape=(), dtype=float32)
# tf.Tensor(3.5193232e-06, shape=(), dtype=float32)
# tf.Tensor(3.5189155e-06, shape=(), dtype=float32)
# tf.Tensor(3.5184771e-06, shape=(), dtype=float32)
# tf.Tensor(3.518157e-06, shape=(), dtype=float32)
# tf.Tensor(3.5178723e-06, shape=(), dtype=float32)
# tf.Tensor(3.5176818e-06, shape=(), dtype=float32)
# tf.Tensor(3.5175017e-06, shape=(), dtype=float32)
# tf.Tensor(3.5173368e-06, shape=(), dtype=float32)
# tf.Tensor(3.5171936e-06, shape=(), dtype=float32)
# tf.Tensor(3.51715e-06, shape=(), dtype=float32)
# tf.Tensor(3.517047e-06, shape=(), dtype=float32)
# tf.Tensor(3.5169342e-06, shape=(), dtype=float32)
# tf.Tensor(3.516905e-06, shape=(), dtype=float32)
# tf.Tensor(3.5168694e-06, shape=(), dtype=float32)
# tf.Tensor(3.5167818e-06, shape=(), dtype=float32)
# tf.Tensor(3.5167534e-06, shape=(), dtype=float32)
# tf.Tensor(3.5167322e-06, shape=(), dtype=float32)
# tf.Tensor(3.5166947e-06, shape=(), dtype=float32)
# tf.Tensor(3.516669e-06, shape=(), dtype=float32)
# tf.Tensor(3.5166636e-06, shape=(), dtype=float32)
# tf.Tensor(3.516649e-06, shape=(), dtype=float32)
# tf.Tensor(3.5166624e-06, shape=(), dtype=float32)
# tf.Tensor(3.5166318e-06, shape=(), dtype=float32)
# tf.Tensor(3.5166245e-06, shape=(), dtype=float32)
# tf.Tensor(3.5165933e-06, shape=(), dtype=float32)
# tf.Tensor(3.5165617e-06, shape=(), dtype=float32)
# tf.Tensor(3.5165626e-06, shape=(), dtype=float32)
# tf.Tensor(3.5165672e-06, shape=(), dtype=float32)
# tf.Tensor(3.5165872e-06, shape=(), dtype=float32)
# running time : 505.0874869823456 seconds
# tf.Tensor(0.010998716, shape=(), dtype=float32)
# tf.Tensor(0.010595983, shape=(), dtype=float32)
# tf.Tensor(0.010239252, shape=(), dtype=float32)
# tf.Tensor(0.009921262, shape=(), dtype=float32)
# tf.Tensor(0.009635965, shape=(), dtype=float32)
# tf.Tensor(0.009378328, shape=(), dtype=float32)
# tf.Tensor(0.0091441525, shape=(), dtype=float32)
# tf.Tensor(0.008929931, shape=(), dtype=float32)
# tf.Tensor(0.00873273, shape=(), dtype=float32)
# tf.Tensor(0.008550091, shape=(), dtype=float32)
# tf.Tensor(0.0083799455, shape=(), dtype=float32)
# tf.Tensor(0.008220563, shape=(), dtype=float32)
# tf.Tensor(0.008070479, shape=(), dtype=float32)
# tf.Tensor(0.007928474, shape=(), dtype=float32)
# tf.Tensor(0.0077935024, shape=(), dtype=float32)
# tf.Tensor(0.007664688, shape=(), dtype=float32)
# tf.Tensor(0.00754129, shape=(), dtype=float32)
# tf.Tensor(0.007422676, shape=(), dtype=float32)
# tf.Tensor(0.007308314, shape=(), dtype=float32)
# tf.Tensor(0.007197745, shape=(), dtype=float32)
# tf.Tensor(0.007090585, shape=(), dtype=float32)
# tf.Tensor(0.006986505, shape=(), dtype=float32)
# tf.Tensor(0.0068852166, shape=(), dtype=float32)
# tf.Tensor(0.0067864805, shape=(), dtype=float32)
# tf.Tensor(0.006690086, shape=(), dtype=float32)
# tf.Tensor(0.0065958565, shape=(), dtype=float32)
# tf.Tensor(0.0065036356, shape=(), dtype=float32)
# tf.Tensor(0.0064132893, shape=(), dtype=float32)
# tf.Tensor(0.0063247033, shape=(), dtype=float32)
# tf.Tensor(0.0062377723, shape=(), dtype=float32)
# tf.Tensor(0.006152413, shape=(), dtype=float32)
# tf.Tensor(0.006068541, shape=(), dtype=float32)
# tf.Tensor(0.0059860917, shape=(), dtype=float32)
# tf.Tensor(0.005905006, shape=(), dtype=float32)
# tf.Tensor(0.005825227, shape=(), dtype=float32)
# tf.Tensor(0.005746707, shape=(), dtype=float32)
# tf.Tensor(0.005669403, shape=(), dtype=float32)
# tf.Tensor(0.00559328, shape=(), dtype=float32)
# tf.Tensor(0.005518296, shape=(), dtype=float32)
# tf.Tensor(0.0054444247, shape=(), dtype=float32)
# tf.Tensor(0.0053716335, shape=(), dtype=float32)
# tf.Tensor(0.005299897, shape=(), dtype=float32)
# tf.Tensor(0.005229187, shape=(), dtype=float32)
# tf.Tensor(0.005159485, shape=(), dtype=float32)
# tf.Tensor(0.0050907675, shape=(), dtype=float32)
# tf.Tensor(0.0050230133, shape=(), dtype=float32)
# tf.Tensor(0.0049562026, shape=(), dtype=float32)
# tf.Tensor(0.004890319, shape=(), dtype=float32)
# tf.Tensor(0.004825344, shape=(), dtype=float32)
# tf.Tensor(0.0047612633, shape=(), dtype=float32)
# tf.Tensor(0.004698058, shape=(), dtype=float32)
# tf.Tensor(0.004635715, shape=(), dtype=float32)
# tf.Tensor(0.004574221, shape=(), dtype=float32)
# tf.Tensor(0.004513559, shape=(), dtype=float32)
# tf.Tensor(0.0044537177, shape=(), dtype=float32)
# tf.Tensor(0.004394681, shape=(), dtype=float32)
# tf.Tensor(0.0043364423, shape=(), dtype=float32)
# tf.Tensor(0.0042789862, shape=(), dtype=float32)
# tf.Tensor(0.004222299, shape=(), dtype=float32)
# tf.Tensor(0.004166371, shape=(), dtype=float32)
# tf.Tensor(0.004111192, shape=(), dtype=float32)
# tf.Tensor(0.004056746, shape=(), dtype=float32)
# tf.Tensor(0.0040030265, shape=(), dtype=float32)
# tf.Tensor(0.0039500236, shape=(), dtype=float32)
# tf.Tensor(0.0038977251, shape=(), dtype=float32)
# tf.Tensor(0.0038461175, shape=(), dtype=float32)
# tf.Tensor(0.0037951958, shape=(), dtype=float32)
# tf.Tensor(0.00374495, shape=(), dtype=float32)
# tf.Tensor(0.0036953688, shape=(), dtype=float32)
# tf.Tensor(0.0036464431, shape=(), dtype=float32)
# tf.Tensor(0.003598167, shape=(), dtype=float32)
# tf.Tensor(0.0035505253, shape=(), dtype=float32)
# tf.Tensor(0.0035035114, shape=(), dtype=float32)
# tf.Tensor(0.0034571174, shape=(), dtype=float32)
# tf.Tensor(0.0034113354, shape=(), dtype=float32)
# tf.Tensor(0.0033661607, shape=(), dtype=float32)
# tf.Tensor(0.0033215755, shape=(), dtype=float32)
# tf.Tensor(0.0032775782, shape=(), dtype=float32)
# tf.Tensor(0.00323416, shape=(), dtype=float32)
# tf.Tensor(0.0031913102, shape=(), dtype=float32)
# tf.Tensor(0.0031490258, shape=(), dtype=float32)
# tf.Tensor(0.0031072968, shape=(), dtype=float32)
# tf.Tensor(0.0030661132, shape=(), dtype=float32)
# tf.Tensor(0.0030254696, shape=(), dtype=float32)
# tf.Tensor(0.0029853613, shape=(), dtype=float32)
# tf.Tensor(0.002945781, shape=(), dtype=float32)
# tf.Tensor(0.002906715, shape=(), dtype=float32)
# tf.Tensor(0.0028681613, shape=(), dtype=float32)
# tf.Tensor(0.0028301133, shape=(), dtype=float32)
# tf.Tensor(0.0027925652, shape=(), dtype=float32)
# tf.Tensor(0.002755507, shape=(), dtype=float32)
# tf.Tensor(0.0027189339, shape=(), dtype=float32)
# tf.Tensor(0.0026828412, shape=(), dtype=float32)
# tf.Tensor(0.0026472188, shape=(), dtype=float32)
# tf.Tensor(0.0026120632, shape=(), dtype=float32)
# tf.Tensor(0.0025773668, shape=(), dtype=float32)
# tf.Tensor(0.0025431262, shape=(), dtype=float32)
# tf.Tensor(0.0025093332, shape=(), dtype=float32)
# tf.Tensor(0.0024759814, shape=(), dtype=float32)
# tf.Tensor(0.0024430652, shape=(), dtype=float32)
# running time : 353.48528361320496 seconds

# %%
plt.plot(losses)
plt.yscale("log")
plt.xlabel("iteration", fontsize = "xx-large")
plt.ylabel("loss", fontsize = "xx-large")
plt.show()

# %%
#X_test = tf.constant([[p0],[q0]])

X_test = tf.constant([[1.],[1.]])
Model = Model_NonRev

p = [Model.run(X_test)[0]]
q = [Model.run(X_test)[1]]

run = [Model.run(X_test)]

for i in range(50):
    run.append(Model.run(run[-1]))
    p.append(run[-1][0])
    q.append(run[-1][1])
    
    
plt.plot(q, p, marker = "o") #, linewidth = 0)
#plot_true_tr(leapfrog, q0, p0, Δt, 40)
plt.xlabel("q", fontsize = "xx-large")
plt.ylabel("p", fontsize = "xx-large")
plt.show()

# %% [markdown]
# ### Reversing Symmetry:
#
# ## $$ R \phi_{t} R = \phi_{-t} $$

# %%
### R-reversibility
def R(X):
    R = tf.concat([[[-1., 0.]], [[0., 1.]]], 0)
    return tf.matmul(R,X)

X_test = tf.constant([[1.],[1.]])
N_test = 50

p_f = [Model.run(X_test)[0]]
q_f = [Model.run(X_test)[1]]
run = [Model.run(X_test)]

for i in range(N_test):
    run.append(Model.run(run[-1]))
    p_f.append(run[-1][0])
    q_f.append(run[-1][1])


X_test = run[-1]

p_b = [R(Model.run(R(X_test)))[0]]
q_b = [R(Model.run(R(X_test)))[1]]
run = [R(Model.run(R(X_test)))]

for i in range(N_test):
    run.append(R(Model.run(R(run[-1]))))
    p_b.append(run[-1][0])
    q_b.append(run[-1][1])


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
fig.suptitle('Reversing Symmetry', fontsize = "xx-large")


ax1.plot(q_f, p_f)
ax1.scatter(q_f[0], p_f[0], label = "starting point")
ax1.legend()
#ax1.set_xlim((0., 2.))
#ax1.set_ylim((-1.5, 1.1))
ax1.set_xlabel("q", fontsize = "x-large")
ax1.set_ylabel("p", fontsize = "x-large")
ax1.set_title("$\phi_{t}$", fontsize = "xx-large")
#plt.show()


ax2.plot(q_b, p_b)
ax2.scatter(q_b[0], p_b[0], label = "starting point")
ax2.legend()
#ax2.set_xlim((0., 2.))
#ax2.set_ylim((-1.5, 1.1))
ax2.set_xlabel("q", fontsize = "x-large")
ax2.set_ylabel("p", fontsize = "x-large")
ax2.set_title("$R \phi_{t} R = \phi_{-t}$", fontsize = "xx-large")

plt.show()
