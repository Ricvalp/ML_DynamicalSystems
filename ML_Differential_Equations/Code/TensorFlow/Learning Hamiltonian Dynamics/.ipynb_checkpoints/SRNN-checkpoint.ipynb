# %%
import tensorflow as tf
import keras
from keras import backend as bk
import timeit

from scipy.integrate import ode
import math as mt
import numpy as np
import matplotlib.pyplot as plt
import random as rdm
import time
from datetime import datetime
import matplotlib.animation as animation
from IPython.display import display, clear_output


physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
class custom_model:

    def __init__(self):
        
        ### Hamiltonian parameters
        self.m = 1.
        self.l = 1.
        
        self.Δt = 0.05
        self.N = 20
        
        ### Neural Networks
        xavier=tf.keras.initializers.GlorotUniform()
        
        self.V1=tf.keras.layers.Dense(1,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.V2=tf.keras.layers.Dense(32,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.V3=tf.keras.layers.Dense(32,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.Vout=tf.keras.layers.Dense(1,kernel_initializer=xavier)
        
        self.K1=tf.keras.layers.Dense(1,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.K2=tf.keras.layers.Dense(32,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.K3=tf.keras.layers.Dense(32,kernel_initializer=xavier,activation=tf.nn.tanh)
        self.Kout=tf.keras.layers.Dense(1,kernel_initializer=xavier)
        
        
        self.train_op = tf.keras.optimizers.Adam(learning_rate=0.02)

    def runV(self, X):
        #with tf.device('/cpu:0'):
        boom = self.V1(X)
        boom1 = self.V2(boom)
        boom2 = self.V3(boom1)
        boom3 = self.Vout(boom2)
        return boom3
    
    def runK(self, X):
        #with tf.device('/cpu:0'):
        boom = self.K1(X)
        boom1 = self.K2(boom)
        boom2 = self.K3(boom1)
        boom3 = self.Kout(boom2)
        return boom3

    ####################################### Leapfrog for NN #######################
    
    def leapfrog_nn(self, q0, p0, Δt, N):
        q = [tf.constant([[q0]])]
        p = [tf.constant([[p0]])]
        p̄ = []
        for i in range(N):
            p̄.append(p[-1] + 0.5*Δt*self.runV(q[-1]))
            q.append(q[-1] + Δt*self.runK(p̄[-1]))
            p.append(p̄[-1] + 0.5*Δt*self.runV(q[-1]))
        return [q, p]
    
    ############################### Generate training dataset from leapfrog ######
    
    ### H = F(p) + T(q) separable Hamiltonian
    def V(self, p):
        return p/(self.m*self.l*self.l)
    
    def K(self, q):
        return -self.m*self.l*tf.math.sin(q)
    
    ### Leapfrog integrator with V and K
    def leapfrog(self, q0, p0, Δt, N):
        q = [tf.constant([[q0]])]
        p = [tf.constant([[p0]])]
        p̄ = []
        for i in range(N):
            p̄.append(p[-1] + 0.5*Δt*self.V(q[-1]))
            q.append(q[-1] + Δt*self.K(p̄[-1]))
            p.append(p̄[-1] + 0.5*Δt*self.V(q[-1]))
        return [q, p]
    
    
    ##################################### Loss function ##########################
    
    def get_loss(self, q0, p0):
        prediction = tf.convert_to_tensor(self.leapfrog_nn(q0, p0, self.Δt, self.N))
        true_trajectory = tf.convert_to_tensor(self.leapfrog(q0, p0, self.Δt, self.N))
        MSE = tf.reduce_sum((prediction - true_trajectory)**2)
        return MSE

    #get gradient
    def get_gradV(self, q0, p0):
        with tf.GradientTape() as tape:
            tape.watch(self.V1.variables)
            tape.watch(self.V2.variables)
            tape.watch(self.V3.variables)
            tape.watch(self.Vout.variables)
            L = self.get_loss(q0, p0)
            g = tape.gradient(L, [self.V1.variables[0],self.V1.variables[1],self.V2.variables[0],self.V2.variables[1],self.V3.variables[0],self.V3.variables[1],self.Vout.variables[0],self.Vout.variables[1]])
        return g
    
    def get_gradK(self, q0, p0):
        with tf.GradientTape() as tape:
            tape.watch(self.K1.variables)
            tape.watch(self.K2.variables)
            tape.watch(self.K3.variables)
            tape.watch(self.Kout.variables)
            L = self.get_loss(q0, p0)
            g = tape.gradient(L, [self.K1.variables[0],self.K1.variables[1],self.K2.variables[0],self.K2.variables[1],self.K3.variables[0],self.K3.variables[1],self.Kout.variables[0],self.Kout.variables[1]])
        return g
    
    # perform gradient descent
    def network_learnV(self, q0, p0):
        
        g = self.get_gradV(q0, p0)
        self.train_op.apply_gradients(zip(g, [self.V1.variables[0],self.V1.variables[1],self.V2.variables[0],self.V2.variables[1],self.V3.variables[0],self.V3.variables[1],self.Vout.variables[0],self.Vout.variables[1]]))


    def network_learnK(self, q0, p0):
        
        g = self.get_gradK(q0, p0)
        self.train_op.apply_gradients(zip(g, [self.K1.variables[0],self.K1.variables[1],self.K2.variables[0],self.K2.variables[1],self.K3.variables[0],self.K3.variables[1],self.Kout.variables[0],self.Kout.variables[1]]))

# %% [markdown]
# ### Untrained Model

# %%
Model = custom_model()

PQ = Model.leapfrog_nn(1., 0.1, 0.05, 20)
q = []
p = []
for i in range(len(PQ[0])):
    q.append(PQ[0][i].numpy()[0][0])
    p.append(PQ[1][i].numpy()[0][0])

plt.plot(q, p)
plt.xlabel("q")
plt.ylabel("p")
plt.show()

# %% [markdown]
# ### Symplectic leapfrog integrator of the form:
#
# ## $$ \begin{equation}
#     \begin{aligned}
#     \textbf{p}_{n+1/2} &= \textbf{p}_{n} + \frac{1}{2} \Delta t V(\textbf{q}_{n})\\
#     \textbf{q}_{n+1} &= \textbf{q}_{n} + \Delta t K(\textbf{p}_{n + 1/2})\\
#     \textbf{p}_{n+1} &= \textbf{p}_{n+1/2} + \frac{1}{2} \Delta t V(\textbf{q}_{n+1})\\
#     \end{aligned}
#     \end{equation}
# $$

# %%
def leapfrog(V, K, q0, p0, Δt, N):
    q = [q0]
    p = [p0]
    p̄ = []
    for i in range(N):
        p̄.append(p[-1] + 0.5*Δt*V(q[-1]))
        q.append(q[-1] + Δt*K(p̄[-1]))
        p.append(p̄[-1] + 0.5*Δt*V(q[-1]))
    return [q, p]

# %% [markdown]
# ### Example

# %%
#Hamilton equations
m = 1.
l = 1.
def V(q):
    return -m*l*mt.sin(q)
def K(p):
    return p/(m*l*l)

#leapfrog integrator parameters
N_p = 20
Δt = 0.05

#other parameters
N_tr = 50
TDataset = []
u0s = []

start_time = time.time()

for i in range(N_tr):
    u0 = [rdm.choice([-1,1])*rdm.random()*3, rdm.choice([-1,1])*rdm.random()*3]
    u0s.append(u0)
    TDataset.append(leapfrog(V, K, u0[0], u0[1], Δt, N_p))

print("running time for " + str(N_tr) + " trajectories of " + str(N_p) + " points each: %s seconds" % (time.time() - start_time))
# Out:
# running time for 50 trajectories of 20 points each: 0.0009980201721191406 seconds

# %% [markdown]
# ### Training Dataset

# %%
for i in range(N_tr):
    plt.scatter(TDataset[i][0], TDataset[i][1])

plt.xlabel("q")
plt.ylabel("p")
plt.show()

# %% [markdown]
# ### Training the model with random initial conditions $(q_{0},p_{0}) \in [-\pi, \pi] \times [-\pi, \pi]$

# %%
epochs = 100
each = 10
losses = []

for i in range(epochs):
    u0 = [rdm.choice([-1,1])*rdm.random()*3, rdm.choice([-1,1])*rdm.random()*3]
    print((i/epochs)*100, "%")
    loss = Model.get_loss(u0[0], u0[1])
    losses.append(loss)
    print("loss = ", loss)
    
    for j in range(each):
        Model.network_learnV(u0[0], u0[1])
        Model.network_learnK(u0[0], u0[1])
# Out:
# 0.0 %
# loss =  tf.Tensor(2.5512505, shape=(), dtype=float32)
# 1.0 %
# loss =  tf.Tensor(3.3676448, shape=(), dtype=float32)
# 2.0 %
# loss =  tf.Tensor(1.8792205, shape=(), dtype=float32)
# 3.0 %
# loss =  tf.Tensor(0.40168053, shape=(), dtype=float32)
# 4.0 %
# loss =  tf.Tensor(0.82546973, shape=(), dtype=float32)
# 5.0 %
# loss =  tf.Tensor(5.146346, shape=(), dtype=float32)
# 6.0 %
# loss =  tf.Tensor(2.0497372, shape=(), dtype=float32)
# 7.000000000000001 %
# loss =  tf.Tensor(5.3251514, shape=(), dtype=float32)
# 8.0 %
# loss =  tf.Tensor(5.935852, shape=(), dtype=float32)
# 9.0 %
# loss =  tf.Tensor(6.1662946, shape=(), dtype=float32)
# 10.0 %
# loss =  tf.Tensor(4.7074666, shape=(), dtype=float32)
# 11.0 %
# loss =  tf.Tensor(1.4957303, shape=(), dtype=float32)
# 12.0 %
# loss =  tf.Tensor(4.8922086, shape=(), dtype=float32)
# 13.0 %
# loss =  tf.Tensor(3.272896, shape=(), dtype=float32)
# 14.000000000000002 %
# loss =  tf.Tensor(0.43455985, shape=(), dtype=float32)
# 15.0 %
# loss =  tf.Tensor(0.69130415, shape=(), dtype=float32)
# 16.0 %
# loss =  tf.Tensor(7.0335665, shape=(), dtype=float32)
# 17.0 %
# loss =  tf.Tensor(0.08662405, shape=(), dtype=float32)
# 18.0 %
# loss =  tf.Tensor(3.9470353, shape=(), dtype=float32)
# 19.0 %
# loss =  tf.Tensor(4.0497346, shape=(), dtype=float32)
# 20.0 %
# loss =  tf.Tensor(0.37732422, shape=(), dtype=float32)
# 21.0 %
# loss =  tf.Tensor(1.4367758, shape=(), dtype=float32)
# 22.0 %
# loss =  tf.Tensor(1.8240068, shape=(), dtype=float32)
# 23.0 %
# loss =  tf.Tensor(1.653084, shape=(), dtype=float32)
# 24.0 %
# loss =  tf.Tensor(1.4373595, shape=(), dtype=float32)
# 25.0 %
# loss =  tf.Tensor(11.877897, shape=(), dtype=float32)
# 26.0 %
# loss =  tf.Tensor(16.68882, shape=(), dtype=float32)
# 27.0 %
# loss =  tf.Tensor(3.0150347, shape=(), dtype=float32)
# 28.000000000000004 %
# loss =  tf.Tensor(23.67527, shape=(), dtype=float32)
# 28.999999999999996 %
# loss =  tf.Tensor(4.2435412, shape=(), dtype=float32)
# 30.0 %
# loss =  tf.Tensor(0.20745045, shape=(), dtype=float32)
# 31.0 %
# loss =  tf.Tensor(1.012692, shape=(), dtype=float32)
# 32.0 %
# loss =  tf.Tensor(0.18233581, shape=(), dtype=float32)
# 33.0 %
# loss =  tf.Tensor(0.26758954, shape=(), dtype=float32)
# 34.0 %
# loss =  tf.Tensor(0.20265275, shape=(), dtype=float32)
# 35.0 %
# loss =  tf.Tensor(0.94970703, shape=(), dtype=float32)
# 36.0 %
# loss =  tf.Tensor(0.68347585, shape=(), dtype=float32)
# 37.0 %
# loss =  tf.Tensor(18.467175, shape=(), dtype=float32)
# 38.0 %
# loss =  tf.Tensor(20.291737, shape=(), dtype=float32)
# 39.0 %
# loss =  tf.Tensor(2.2646484, shape=(), dtype=float32)
# 40.0 %
# loss =  tf.Tensor(6.4507318, shape=(), dtype=float32)
# 41.0 %
# loss =  tf.Tensor(0.3890758, shape=(), dtype=float32)
# 42.0 %
# loss =  tf.Tensor(11.913353, shape=(), dtype=float32)
# 43.0 %
# loss =  tf.Tensor(6.0920353, shape=(), dtype=float32)
# 44.0 %
# loss =  tf.Tensor(0.8063534, shape=(), dtype=float32)
# 45.0 %
# loss =  tf.Tensor(1.5944648, shape=(), dtype=float32)
# 46.0 %
# loss =  tf.Tensor(1.7011547, shape=(), dtype=float32)
# 47.0 %
# loss =  tf.Tensor(0.037022464, shape=(), dtype=float32)
# 48.0 %
# loss =  tf.Tensor(1.5277106, shape=(), dtype=float32)
# 49.0 %
# loss =  tf.Tensor(0.039104514, shape=(), dtype=float32)
# 50.0 %
# loss =  tf.Tensor(9.61204, shape=(), dtype=float32)
# 51.0 %
# loss =  tf.Tensor(8.400305, shape=(), dtype=float32)
# 52.0 %
# loss =  tf.Tensor(12.188082, shape=(), dtype=float32)
# 53.0 %
# loss =  tf.Tensor(79.559204, shape=(), dtype=float32)
# 54.0 %
# loss =  tf.Tensor(0.15850143, shape=(), dtype=float32)
# 55.00000000000001 %
# loss =  tf.Tensor(10.250862, shape=(), dtype=float32)
# 56.00000000000001 %
# loss =  tf.Tensor(13.373266, shape=(), dtype=float32)
# 56.99999999999999 %
# loss =  tf.Tensor(26.707678, shape=(), dtype=float32)
# 57.99999999999999 %
# loss =  tf.Tensor(39.702446, shape=(), dtype=float32)
# 59.0 %
# loss =  tf.Tensor(5.478114, shape=(), dtype=float32)
# 60.0 %
# loss =  tf.Tensor(2.6255283, shape=(), dtype=float32)
# 61.0 %
# loss =  tf.Tensor(27.518867, shape=(), dtype=float32)
# 62.0 %
# loss =  tf.Tensor(46.04528, shape=(), dtype=float32)
# 63.0 %
# loss =  tf.Tensor(25.1774, shape=(), dtype=float32)
# 64.0 %
# loss =  tf.Tensor(22.680645, shape=(), dtype=float32)
# 65.0 %
# loss =  tf.Tensor(26.520222, shape=(), dtype=float32)
# 66.0 %
# loss =  tf.Tensor(9.171599, shape=(), dtype=float32)
# 67.0 %
# loss =  tf.Tensor(8.540894, shape=(), dtype=float32)
# 68.0 %
# loss =  tf.Tensor(16.72403, shape=(), dtype=float32)
# 69.0 %
# loss =  tf.Tensor(0.28664958, shape=(), dtype=float32)
# 70.0 %
# loss =  tf.Tensor(9.03087, shape=(), dtype=float32)
# 71.0 %
# loss =  tf.Tensor(1.2014672, shape=(), dtype=float32)
# 72.0 %
# loss =  tf.Tensor(10.4815235, shape=(), dtype=float32)
# 73.0 %
# loss =  tf.Tensor(27.702583, shape=(), dtype=float32)
# 74.0 %
# loss =  tf.Tensor(34.795486, shape=(), dtype=float32)
# 75.0 %
# loss =  tf.Tensor(13.992569, shape=(), dtype=float32)
# 76.0 %
# loss =  tf.Tensor(2.2248483, shape=(), dtype=float32)
# 77.0 %
# loss =  tf.Tensor(4.593302, shape=(), dtype=float32)
# 78.0 %
# loss =  tf.Tensor(4.6885633, shape=(), dtype=float32)
# 79.0 %
# loss =  tf.Tensor(2.8082871, shape=(), dtype=float32)
# 80.0 %
# loss =  tf.Tensor(3.9454389, shape=(), dtype=float32)
# 81.0 %
# loss =  tf.Tensor(0.9905186, shape=(), dtype=float32)
# 82.0 %
# loss =  tf.Tensor(16.979113, shape=(), dtype=float32)
# 83.0 %
# loss =  tf.Tensor(1.1041445, shape=(), dtype=float32)
# 84.0 %
# loss =  tf.Tensor(3.080757, shape=(), dtype=float32)
# 85.0 %
# loss =  tf.Tensor(7.610803, shape=(), dtype=float32)
# 86.0 %
# loss =  tf.Tensor(0.5411588, shape=(), dtype=float32)
# 87.0 %
# loss =  tf.Tensor(4.494029, shape=(), dtype=float32)
# 88.0 %
# loss =  tf.Tensor(0.22875318, shape=(), dtype=float32)
# 89.0 %
# loss =  tf.Tensor(15.277496, shape=(), dtype=float32)
# 90.0 %
# loss =  tf.Tensor(24.517818, shape=(), dtype=float32)
# 91.0 %
# loss =  tf.Tensor(27.105331, shape=(), dtype=float32)
# 92.0 %
# loss =  tf.Tensor(9.739683, shape=(), dtype=float32)
# 93.0 %
# loss =  tf.Tensor(2.200858, shape=(), dtype=float32)
# 94.0 %
# loss =  tf.Tensor(6.6443105, shape=(), dtype=float32)
# 95.0 %
# loss =  tf.Tensor(6.862748, shape=(), dtype=float32)
# 96.0 %
# loss =  tf.Tensor(28.22852, shape=(), dtype=float32)
# 97.0 %
# loss =  tf.Tensor(16.184113, shape=(), dtype=float32)
# 98.0 %
# loss =  tf.Tensor(46.394257, shape=(), dtype=float32)
# 99.0 %
# loss =  tf.Tensor(12.739396, shape=(), dtype=float32)

# %% [markdown]
# ### Trained model

# %%
for i in range(10):
    PQ = Model.leapfrog_nn(rdm.choice([-1,1])*rdm.random()*3, rdm.choice([-1,1])*rdm.random()*3, 0.01, 500)
    p = []
    q = []
    for i in range(len(PQ[0])):
        q.append(PQ[0][i].numpy()[0][0])
        p.append(PQ[1][i].numpy()[0][0])

    plt.plot(q, p)

plt.xlabel("q")
plt.ylabel("p")
plt.show()

# %% [markdown]
# ### Training the model along one single trajectory

# %%
Model = custom_model()
losses = []
epochs = 1000
q0 = 1.
p0 = 0.3

start_time = time.time()

for i in range(epochs):
    if i%1 == 0:
        clear_output(wait=True)
        display(str((i/epochs)*100) + "%")  
    losses.append(Model.get_loss(q0, p0).numpy())
    Model.network_learnV(q0, p0)
    Model.network_learnK(q0, p0)

print("Training time: %s seconds" % (time.time() - start_time))
# Out:
# '99.9%'
# Training time: 229.02951788902283 seconds

# %% [markdown]
# ### Plot the loss

# %%
plt.plot(losses)
plt.yscale("log")
plt.ylabel("loss")
plt.xlabel("iteration")
plt.show()

# %% [markdown]
# ### Trained model: plot the result

# %%
plt.figure(figsize=(15,10))

for i in range(5):
    q0_test, p0_test, dt_test, N_test = [i*0.5, 0., 0.05, 200]

    PQ_nn = Model.leapfrog_nn(q0_test, p0_test, dt_test, N_test)
    q_nn = []
    p_nn = []
    for i in range(len(PQ_nn[0])):
        q_nn.append(PQ_nn[0][i].numpy()[0][0])
        p_nn.append(PQ_nn[1][i].numpy()[0][0])
    plt.scatter(p_nn, q_nn)

    PQ = Model.leapfrog(q0_test, p0_test, dt_test, N_test)
    q = []
    p = []
    for i in range(len(PQ[0])):
        q.append(PQ[0][i].numpy()[0][0])
        p.append(PQ[1][i].numpy()[0][0])
    plt.plot(p, q)

#plt.legend(('Trained', 'True'), loc='upper right')
plt.xlabel("q")
plt.ylabel("p")
plt.show()
