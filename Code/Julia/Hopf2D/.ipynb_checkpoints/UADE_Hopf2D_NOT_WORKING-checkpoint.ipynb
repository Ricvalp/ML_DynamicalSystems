# %%
using OrdinaryDiffEq
using ModelingToolkit
using DataDrivenDiffEq
using LinearAlgebra, DiffEqSensitivity, Optim
using DiffEqFlux, Flux
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# ## Generate the (noisy) training dataset from:
#
#
# ## $$
# \begin{aligned}
#   \dot{x} &= \mu x - \omega y + A_{1} x(x^{2} + y^{2})\\
#   \dot{y} &=  \mu y + \omega y + A_{2} y(x^{2} + y^{2})\\
#   A_{1} &= A_{2}
# \end{aligned}
# $$

# %%
function Hopf2D(du, u, p, t)
    μ, ω, A1, A2 = p
    du[1] = μ*u[1] - ω*u[2] + A1*u[1]*(u[1]^(2) + u[2]^(2))
    du[2] = μ*u[2] + ω*u[1] + A2*u[2]*(u[1]^(2) + u[2]^(2))
end


# Define the experimental parameter

tspan = (0.0f0, 4.5f0)
u0 = Float32[-0.2, 0.2]
p_ = Float32[0.8, 1.2, -1.5, -1.5]

prob = ODEProblem(Hopf2D, u0, tspan, p_)

saveat = 0.05

solution = solve(prob, Vern7(), abstol=1e-12, reltol=1e-12, saveat = saveat)


X = Array(solution)

# Add noise to the data
println("Generate noisy data")
Xₙ = X + Float32(1e-4)*randn(eltype(X), size(X));
# Out:
# Generate noisy data

# %% [markdown]
# ## Plot The Training Dataset

# %%
#plot(solution)
#plot(Array(solution)[1, :], Array(solution)[2, :])
#plot(Xₙ[1, :], Xₙ[2, :])
plot(solution.t, Xₙ[1, :])
plot!(solution.t, Xₙ[2, :])

# %% [markdown]
# ## UADE

# %%
# Neural network

L = FastChain(FastDense(2, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 32, tanh), FastDense(32, 2))
p = initial_params(L)


# ODE

function dudt_(u, p, t)
    x, y = u
    z = L(u,p)
    [p_[1]*x - p_[2]*y + z[1],
    p_[2]*x + p_[1]*y + z[2]]
end

# ODE problem

prob_nn = ODEProblem(dudt_, u0, tspan, p)
sol_nn = solve(prob_nn, Tsit5(), u0 = u0, p = p, saveat = solution.t);

# %% [markdown]
# ## PLot The Untrained Solution

# %%
plot(sol_nn)
#plot(Array(sol_nn)[1, :], Array(sol_nn)[2, :])

# %% [markdown]
# ## Loss Function

# %%
# This function is used in the loss
function predict(θ)
    Array(solve(prob_nn, Vern7(), u0 = u0, p=θ, saveat = solution.t,
                         abstol=1e-6, reltol=1e-6,
                         sensealg = InterpolatingAdjoint(autojacvec=ReverseDiffVJP())))
end


# No regularisation right now
function loss(θ)
    pred = predict(θ)
    sum(abs2, Xₙ .- pred)
end


# Test
#loss(p)


const losses = []

# The callback function is cb(p,args...) where the arguments are the extra returns from the loss
callback(θ, l) = begin
    push!(losses, l)
    if length(losses)%10==0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")    
    end
    
    # The callback function must return a boolean where if true, then the optimizer will prematurely end the optimization
    false
end
# Out:
# callback (generic function with 1 method)

# %% [markdown]
# ## Training With ADAM

# %%
# Train with ADAM
res1 = DiffEqFlux.sciml_train(loss, p, ADAM(0.01), cb=callback, maxiters = 400)
# Out:
# loss: 39.9:   2%|█                                      |  ETA: 0:06:18
# Current loss after 10 iterations: 39.850494
# loss: 35.5:   5%|██                                     |  ETA: 0:04:51
# Current loss after 20 iterations: 35.492092
# loss: 33.5:   8%|███                                    |  ETA: 0:04:09
# Current loss after 30 iterations: 33.507866
# loss: 32.3:  10%|████                                   |  ETA: 0:03:47
# Current loss after 40 iterations: 32.315033
# loss: 31.6:  12%|█████                                  |  ETA: 0:03:31
# Current loss after 50 iterations: 31.55221
# loss: 31:  15%|███████                                  |  ETA: 0:03:16
# Current loss after 60 iterations: 31.048897
# loss: 30.7:  18%|███████                                |  ETA: 0:03:04
# Current loss after 70 iterations: 30.70448
# loss: 30.5:  20%|████████                               |  ETA: 0:02:56
# Current loss after 80 iterations: 30.453604
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.245438e-01
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   320  (vs limit Inf)
#     Iterations:    400
#     f(x) calls:    400
#     ∇f(x) calls:   400

# %% [markdown]
# ## Training with BFGS

# %%
res2 = DiffEqFlux.sciml_train(loss, res1.minimizer, BFGS(initial_stepnorm=0.01), cb=callback, maxiters = 10000)
# Out:
# Current loss after 410 iterations: 0.029953858
# Current loss after 420 iterations: 0.0105780065
# Current loss after 430 iterations: 0.006637761
# Current loss after 440 iterations: 0.0013421959
# Current loss after 450 iterations: 0.000638693
# Current loss after 460 iterations: 0.000496725
# Current loss after 470 iterations: 0.00029983468
# Current loss after 480 iterations: 0.00020044453
# Current loss after 490 iterations: 0.000104854764
# Current loss after 500 iterations: 7.412378e-5
# Current loss after 510 iterations: 4.8575217e-5
# Current loss after 520 iterations: 4.2256586e-5
# Current loss after 530 iterations: 3.6054087e-5
# Current loss after 540 iterations: 3.3337255e-5
# Current loss after 550 iterations: 2.0247586e-5
# Current loss after 560 iterations: 1.7411447e-5
# Current loss after 570 iterations: 1.6975637e-5
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.694151e-05
#
#  * Found with
#     Algorithm:     BFGS
#
#  * Convergence measures
#     |x - x'|               = 0.00e+00 ≤ 0.0e+00
#     |x - x'|/|x'|          = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 7.99e-04 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   214  (vs limit Inf)
#     Iterations:    175
#     f(x) calls:    688
#     ∇f(x) calls:   688

# %% [markdown]
# ## Plot The Prediction

# %%
NNsolution = predict(res2.minimizer)
# Trained on noisy data vs real solution
plot(solution.t, NNsolution', label = ["Learned x(t)" "Learned y(t)"])
scatter!(solution.t, X', label = ["True x(t)" "True y(t)"])

# %% [markdown]
# ## Prediction

# %%
function dudt_(u, p, t)
    x, y = u
    z = L(u, p)
    [p_[1]*x - p_[2]*y + z[1],
    p_[2]*x + p_[1]*y + z[2]]
end

# ODE problem
tspan2 = (0.0f0, 6.0f0)
prob_nn2 = ODEProblem(dudt_, u0, tspan2, res2.minimizer)
sol_nn2 = solve(prob_nn2, Tsit5(), u0 = u0, saveat = 0.05);

# %% [markdown]
# ## Test The Prediction

# %%
tspan_test = (0.0f0, 6.0f0)
prob_test = ODEProblem(Hopf2D, u0, tspan_test, p_)
solution_test = solve(prob_test, Vern7(), abstol=1e-12, reltol=1e-12, saveat = 0.05);

# %% [markdown]
# ## Plot Toghether True And Prediction
# ### Phase Space Plot

# %%
scatter(Array(sol_nn2)[1, :], Array(sol_nn2)[2, :], xlabel = "x", ylabel = "y", label = "learned")
plot!(Array(solution_test)[1, :], Array(solution_test)[2, :], label = "true")

# %% [markdown]
# ## Plot $x(t)$ and $y(t)$

# %%
plot(sol_nn2, label = ["learned x" "learned y"])
scatter!(solution_test.t, Array(solution_test)[1, :], label = "true x")
scatter!(solution_test.t, Array(solution_test)[2, :], label = "true x")

# %% [markdown]
# -----------------------------------------
# -----------------------------------------
# -----------------------------------------

# %% [markdown]
# # SINDy Sparse Identification of Non-linear Dynamics
# ### Ideal derivatives:
# ### we take derivatives with respect to $t$ of $(x(t), y(t))$ both from the known solution and the solution to the trained UADE

# %%
DX = Array(solution(solution.t, Val{1})) 

prob_nn2 = ODEProblem(dudt_, u0, tspan, res2.minimizer)
_sol = solve(prob_nn2, Tsit5())

DX_ = Array(_sol(solution.t, Val{1}))

plot(solution.t, DX', label = ["True x'" " True y'"])
plot!(solution.t, DX_', label = ["Learned x'" "Learned y'"])

# %% [markdown]
# ## The learned derivatives

# %%
# Ideal data
L̄ = [p_[3]*(Xₙ[1,:].^(3) + Xₙ[1,:].*Xₙ[2,:].^(2))'; p_[4]*(Xₙ[2,:].*Xₙ[1,:].^(2) + Xₙ[2,:].^(3))']

# Neural network guess
L̂ = L(Xₙ, res2.minimizer)

scatter(solution.t, L̄', label = ["L̄₁" "L̄₂"])
plot!(solution.t, L̂', label = ["L̂₁" "L̂₂"])


#savefig("UADE.png")

# Plot the error
#scatter(abs.(L̄-L̂)', yaxis = :log)

# %% [markdown]
# ## Create a basis for the sparse identification

# %%
@variables u[1:2]

# Lots of polynomials
polys = Operation[1]

for i ∈ 1:5
    push!(polys, u[1]^i)
    push!(polys, u[2]^i)
    for j ∈ i:5
        if i != j
            push!(polys, (u[1]^i)*(u[2]^j))
            push!(polys, u[2]^i*u[1]^i)
        end
    end
end

# And some other stuff
h = [cos.(u)...; sin.(u)...; polys...]
basis = Basis(h, u)
# Out:
# 29 dimensional basis in ["u₁", "u₂"]

# %% [markdown]
# ## Optimizer for the algorithm

# %%
opt = SR3() #STRRidge(0.1)


# Create the thresholds which should be used in the search process
λ = exp10.(-7:0.1:3)

# Target function to choose the results from; x = L0 of coefficients and L2-Error of the model
g(x) = x[1] < 1 ? Inf : norm(x, 2)

#Suggestion from AlCap23
#g(x) = x[1] < 1 ? Inf : norm([0.1; 10.0] .* x, 2)
# Out:
# g (generic function with 1 method)

# %% [markdown]
# ## Define the ODE with the new identified unknown term

# %%
unknown_sys = ODESystem(Ψ)
unknown_eq = ODEFunction(unknown_sys);

# %%
function dudt(du, u, p, t)
    μ, ω, A1, A2 = p
    z = unknown_eq(u, [A1; A2], t)
    du[1] = μ*u[1] - ω*u[1] + z[1]
    du[2] = ω*u[2] + μ*u[2] + z[2]
end
# Out:
# dudt (generic function with 1 method)

# %% [markdown]
# ## Create the approximated problem and solution

# %%
ps = [p_[[1,2]]; p̂]
#tspan = (0.0f0, 4.0f0)
approximate_prob = ODEProblem(dudt, u0, (0.0f0, 2.0f0), ps)
approximate_solution = solve(approximate_prob, Tsit5(), saveat = 0.1)

# Plot
plot(solution, label = ["True x(t)" "True y(t)"])
scatter!(approximate_solution, label = ["Approx. x(t)" "Approx. y(t)"])
# Out:
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase C:\Users\valpe\.julia\packages\DiffEqBase\3iigH\src\integrator_interface.jl:349

# %% [markdown]
# ## Plot the sparse regression and the trained UA

# %%
# Ideal data
L̄ = [(p̂[2]*Xₙ[1,:].^(3) + p̂[1]*Xₙ[1,:].*Xₙ[2,:].^(2))'; p̂[3]*Xₙ[2,:]']

# Neural network guess
L̂ = L(Xₙ, res2.minimizer)

scatter(solution.t, L̄', label = ["p̂₂*u₁^3 + p̂₁*u₁*u₂^2" "p̂₃*u₂"], title = "Sparse regression and trained UA, training tspan = [0, 4.5]")
plot!(solution.t, L̂', label = ["Trained L̂₁" "Trained L̂₂"])


#savefig("SparseAndUADE_045.png")

# Plot the error
#scatter(abs.(L̄-L̂)', yaxis = :log)
